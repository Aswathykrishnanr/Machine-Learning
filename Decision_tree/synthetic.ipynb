# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('synthetic_health.csv')
df
# Out:
#              Age   Weight    Height         BMI Blood Pressure Heart Rate  \
# 0     56.0 years  97.7 kg  167.7 cm  24.1 kg/m²     137.0 mmHg   91.0 bpm
# 1     69.0 years  66.9 kg  173.4 cm  20.9 kg/m²     145.0 mmHg   60.0 bpm
# 2     46.0 years  91.2 kg  189.0 cm  19.8 kg/m²     133.0 mmHg   84.0 bpm
# 3     32.0 years  55.4 kg  171.3 cm  33.4 kg/m²     102.0 mmHg   94.0 bpm
# 4     60.0 years      NaN  186.2 cm  35.0 kg/m²      93.0 mmHg   69.0 bpm
# ...          ...      ...       ...         ...            ...        ...
# 4995  24.0 years  97.3 kg  163.7 cm  24.6 kg/m²     152.0 mmHg   98.0 bpm
# 4996  66.0 years  85.1 kg  188.8 cm  22.1 kg/m²     153.0 mmHg   56.0 bpm
# 4997  26.0 years  47.9 kg  177.8 cm  24.3 kg/m²     121.0 mmHg   83.0 bpm
# 4998  53.0 years  93.6 kg  166.1 cm  19.9 kg/m²      98.0 mmHg   90.0 bpm
# 4999  36.0 years  92.4 kg  157.7 cm  34.5 kg/m²     100.0 mmHg   61.0 bpm
#
#       Cholesterol      Glucose  Calcium      Iron Vitamin D  \
# 0     197.5 mg/dL  104.3 mg/dL   8.3 mg  110.8 mg   51.9 µg
# 1     215.3 mg/dL  169.8 mg/dL   8.8 mg  149.4 mg   33.3 µg
# 2     223.7 mg/dL  157.7 mg/dL  10.6 mg   82.1 mg   51.3 µg
# 3     176.3 mg/dL  147.6 mg/dL   8.1 mg  154.4 mg   11.7 µg
# 4     133.6 mg/dL  134.8 mg/dL   9.8 mg   51.7 mg   31.3 µg
# ...           ...          ...      ...       ...       ...
# 4995  220.0 mg/dL  139.7 mg/dL  10.0 mg   50.5 mg   24.4 µg
# 4996  250.4 mg/dL  149.0 mg/dL  10.5 mg   40.7 mg   29.9 µg
# 4997  195.4 mg/dL  133.4 mg/dL  10.8 mg   61.1 mg   57.4 µg
# 4998  184.7 mg/dL  177.4 mg/dL  10.0 mg  153.3 mg   30.4 µg
# 4999  197.4 mg/dL  173.9 mg/dL   8.6 mg  109.6 mg   25.8 µg
#
#              Health_Status
# 0     Vitamin D Deficiency
# 1          Iron Deficiency
# 2                  Obesity
# 3                  Obesity
# 4     Vitamin D Deficiency
# ...                    ...
# 4995               Healthy
# 4996               Healthy
# 4997               High BP
# 4998               Healthy
# 4999               Obesity
#
# [5000 rows x 12 columns]

# %%
df.shape
# Out:
# (5000, 12)

# %%
df.tail()
# Out:
#              Age   Weight    Height         BMI Blood Pressure Heart Rate  \
# 4995  24.0 years  97.3 kg  163.7 cm  24.6 kg/m²     152.0 mmHg   98.0 bpm
# 4996  66.0 years  85.1 kg  188.8 cm  22.1 kg/m²     153.0 mmHg   56.0 bpm
# 4997  26.0 years  47.9 kg  177.8 cm  24.3 kg/m²     121.0 mmHg   83.0 bpm
# 4998  53.0 years  93.6 kg  166.1 cm  19.9 kg/m²      98.0 mmHg   90.0 bpm
# 4999  36.0 years  92.4 kg  157.7 cm  34.5 kg/m²     100.0 mmHg   61.0 bpm
#
#       Cholesterol      Glucose  Calcium      Iron Vitamin D Health_Status
# 4995  220.0 mg/dL  139.7 mg/dL  10.0 mg   50.5 mg   24.4 µg       Healthy
# 4996  250.4 mg/dL  149.0 mg/dL  10.5 mg   40.7 mg   29.9 µg       Healthy
# 4997  195.4 mg/dL  133.4 mg/dL  10.8 mg   61.1 mg   57.4 µg       High BP
# 4998  184.7 mg/dL  177.4 mg/dL  10.0 mg  153.3 mg   30.4 µg       Healthy
# 4999  197.4 mg/dL  173.9 mg/dL   8.6 mg  109.6 mg   25.8 µg       Obesity

# %%
df.head()
# Out:
#           Age   Weight    Height         BMI Blood Pressure Heart Rate  \
# 0  56.0 years  97.7 kg  167.7 cm  24.1 kg/m²     137.0 mmHg   91.0 bpm
# 1  69.0 years  66.9 kg  173.4 cm  20.9 kg/m²     145.0 mmHg   60.0 bpm
# 2  46.0 years  91.2 kg  189.0 cm  19.8 kg/m²     133.0 mmHg   84.0 bpm
# 3  32.0 years  55.4 kg  171.3 cm  33.4 kg/m²     102.0 mmHg   94.0 bpm
# 4  60.0 years      NaN  186.2 cm  35.0 kg/m²      93.0 mmHg   69.0 bpm
#
#    Cholesterol      Glucose  Calcium      Iron Vitamin D         Health_Status
# 0  197.5 mg/dL  104.3 mg/dL   8.3 mg  110.8 mg   51.9 µg  Vitamin D Deficiency
# 1  215.3 mg/dL  169.8 mg/dL   8.8 mg  149.4 mg   33.3 µg       Iron Deficiency
# 2  223.7 mg/dL  157.7 mg/dL  10.6 mg   82.1 mg   51.3 µg               Obesity
# 3  176.3 mg/dL  147.6 mg/dL   8.1 mg  154.4 mg   11.7 µg               Obesity
# 4  133.6 mg/dL  134.8 mg/dL   9.8 mg   51.7 mg   31.3 µg  Vitamin D Deficiency

# %%
df.dtypes
# Out:
# Age               object
# Weight            object
# Height            object
# BMI               object
# Blood Pressure    object
# Heart Rate        object
# Cholesterol       object
# Glucose           object
# Calcium           object
# Iron              object
# Vitamin D         object
# Health_Status     object
# dtype: object

# %%
df.isna().sum()
# Out:
# Age                 0
# Weight            250
# Height              0
# BMI                 0
# Blood Pressure    250
# Heart Rate          0
# Cholesterol       250
# Glucose           250
# Calcium             0
# Iron                0
# Vitamin D           0
# Health_Status       0
# dtype: int64

# %%
age=df['Age'].value_counts()
plt.bar(age.index,age.values)
# Out:
# <BarContainer object of 52 artists>

# %%
df.corr(numeric_only=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df
# Out:
#              Age   Weight    Height         BMI Blood Pressure Heart Rate  \
# 0     56.0 years  97.7 kg  167.7 cm  24.1 kg/m²     137.0 mmHg   91.0 bpm
# 1     69.0 years  66.9 kg  173.4 cm  20.9 kg/m²     145.0 mmHg   60.0 bpm
# 2     46.0 years  91.2 kg  189.0 cm  19.8 kg/m²     133.0 mmHg   84.0 bpm
# 3     32.0 years  55.4 kg  171.3 cm  33.4 kg/m²     102.0 mmHg   94.0 bpm
# 4     60.0 years      NaN  186.2 cm  35.0 kg/m²      93.0 mmHg   69.0 bpm
# ...          ...      ...       ...         ...            ...        ...
# 4995  24.0 years  97.3 kg  163.7 cm  24.6 kg/m²     152.0 mmHg   98.0 bpm
# 4996  66.0 years  85.1 kg  188.8 cm  22.1 kg/m²     153.0 mmHg   56.0 bpm
# 4997  26.0 years  47.9 kg  177.8 cm  24.3 kg/m²     121.0 mmHg   83.0 bpm
# 4998  53.0 years  93.6 kg  166.1 cm  19.9 kg/m²      98.0 mmHg   90.0 bpm
# 4999  36.0 years  92.4 kg  157.7 cm  34.5 kg/m²     100.0 mmHg   61.0 bpm
#
#       Cholesterol      Glucose  Calcium      Iron Vitamin D  \
# 0     197.5 mg/dL  104.3 mg/dL   8.3 mg  110.8 mg   51.9 µg
# 1     215.3 mg/dL  169.8 mg/dL   8.8 mg  149.4 mg   33.3 µg
# 2     223.7 mg/dL  157.7 mg/dL  10.6 mg   82.1 mg   51.3 µg
# 3     176.3 mg/dL  147.6 mg/dL   8.1 mg  154.4 mg   11.7 µg
# 4     133.6 mg/dL  134.8 mg/dL   9.8 mg   51.7 mg   31.3 µg
# ...           ...          ...      ...       ...       ...
# 4995  220.0 mg/dL  139.7 mg/dL  10.0 mg   50.5 mg   24.4 µg
# 4996  250.4 mg/dL  149.0 mg/dL  10.5 mg   40.7 mg   29.9 µg
# 4997  195.4 mg/dL  133.4 mg/dL  10.8 mg   61.1 mg   57.4 µg
# 4998  184.7 mg/dL  177.4 mg/dL  10.0 mg  153.3 mg   30.4 µg
# 4999  197.4 mg/dL  173.9 mg/dL   8.6 mg  109.6 mg   25.8 µg
#
#              Health_Status
# 0     Vitamin D Deficiency
# 1          Iron Deficiency
# 2                  Obesity
# 3                  Obesity
# 4     Vitamin D Deficiency
# ...                    ...
# 4995               Healthy
# 4996               Healthy
# 4997               High BP
# 4998               Healthy
# 4999               Obesity
#
# [5000 rows x 12 columns]

# %%
#string replace
df['Age']=df['Age'].str.replace('years','')
df['Weight']=df['Weight'].str.replace('kg','')
df['Height']=df['Height'].str.replace('cm','')
df['BMI']=df['BMI'].str.replace('kg/m²','')
df['Blood Pressure']=df['Blood Pressure'].str.replace('mmHg','')
df['Heart Rate']=df['Heart Rate'].str.replace('bpm','')
df['Cholesterol']=df['Cholesterol'].str.replace('mg/dL','')
df['Glucose']=df['Glucose'].str.replace('mg/dL','')
df['Calcium']=df['Calcium'].str.replace('mg','')
df['Iron']=df['Iron'].str.replace('mg','')
df['Vitamin D']=df['Vitamin D'].str.replace('µg','')
df
# Out:
#         Age Weight  Height    BMI Blood Pressure Heart Rate Cholesterol  \
# 0     56.0   97.7   167.7   24.1          137.0       91.0       197.5
# 1     69.0   66.9   173.4   20.9          145.0       60.0       215.3
# 2     46.0   91.2   189.0   19.8          133.0       84.0       223.7
# 3     32.0   55.4   171.3   33.4          102.0       94.0       176.3
# 4     60.0     NaN  186.2   35.0           93.0       69.0       133.6
# ...     ...    ...     ...    ...            ...        ...         ...
# 4995  24.0   97.3   163.7   24.6          152.0       98.0       220.0
# 4996  66.0   85.1   188.8   22.1          153.0       56.0       250.4
# 4997  26.0   47.9   177.8   24.3          121.0       83.0       195.4
# 4998  53.0   93.6   166.1   19.9           98.0       90.0       184.7
# 4999  36.0   92.4   157.7   34.5          100.0       61.0       197.4
#
#      Glucose Calcium    Iron Vitamin D         Health_Status
# 0     104.3     8.3   110.8      51.9   Vitamin D Deficiency
# 1     169.8     8.8   149.4      33.3        Iron Deficiency
# 2     157.7    10.6    82.1      51.3                Obesity
# 3     147.6     8.1   154.4      11.7                Obesity
# 4     134.8     9.8    51.7      31.3   Vitamin D Deficiency
# ...      ...     ...     ...       ...                   ...
# 4995  139.7    10.0    50.5      24.4                Healthy
# 4996  149.0    10.5    40.7      29.9                Healthy
# 4997  133.4    10.8    61.1      57.4                High BP
# 4998  177.4    10.0   153.3      30.4                Healthy
# 4999  173.9     8.6   109.6      25.8                Obesity
#
# [5000 rows x 12 columns]

# %%
df.dtypes
# Out:
# Age               object
# Weight            object
# Height            object
# BMI               object
# Blood Pressure    object
# Heart Rate        object
# Cholesterol       object
# Glucose           object
# Calcium           object
# Iron              object
# Vitamin D         object
# Health_Status     object
# dtype: object

# %%
x=df.iloc[:,:-1]
x
# Out:
#         Age Weight  Height    BMI Blood Pressure Heart Rate Cholesterol  \
# 0     56.0   97.7   167.7   24.1          137.0       91.0       197.5
# 1     69.0   66.9   173.4   20.9          145.0       60.0       215.3
# 2     46.0   91.2   189.0   19.8          133.0       84.0       223.7
# 3     32.0   55.4   171.3   33.4          102.0       94.0       176.3
# 4     60.0     NaN  186.2   35.0           93.0       69.0       133.6
# ...     ...    ...     ...    ...            ...        ...         ...
# 4995  24.0   97.3   163.7   24.6          152.0       98.0       220.0
# 4996  66.0   85.1   188.8   22.1          153.0       56.0       250.4
# 4997  26.0   47.9   177.8   24.3          121.0       83.0       195.4
# 4998  53.0   93.6   166.1   19.9           98.0       90.0       184.7
# 4999  36.0   92.4   157.7   34.5          100.0       61.0       197.4
#
#      Glucose Calcium    Iron Vitamin D
# 0     104.3     8.3   110.8      51.9
# 1     169.8     8.8   149.4      33.3
# 2     157.7    10.6    82.1      51.3
# 3     147.6     8.1   154.4      11.7
# 4     134.8     9.8    51.7      31.3
# ...      ...     ...     ...       ...
# 4995  139.7    10.0    50.5      24.4
# 4996  149.0    10.5    40.7      29.9
# 4997  133.4    10.8    61.1      57.4
# 4998  177.4    10.0   153.3      30.4
# 4999  173.9     8.6   109.6      25.8
#
# [5000 rows x 11 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       Vitamin D Deficiency
# 1            Iron Deficiency
# 2                    Obesity
# 3                    Obesity
# 4       Vitamin D Deficiency
#                 ...
# 4995                 Healthy
# 4996                 Healthy
# 4997                 High BP
# 4998                 Healthy
# 4999                 Obesity
# Name: Health_Status, Length: 5000, dtype: object

# %%
for i in x.columns:
    if x[i].dtype == "object":
        x[i]=x[i].astype(float)
x.dtypes
# Out:
# Age               float64
# Weight            float64
# Height            float64
# BMI               float64
# Blood Pressure    float64
# Heart Rate        float64
# Cholesterol       float64
# Glucose           float64
# Calcium           float64
# Iron              float64
# Vitamin D         float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Age                 0
# Weight            250
# Height              0
# BMI                 0
# Blood Pressure    250
# Heart Rate          0
# Cholesterol       250
# Glucose           250
# Calcium             0
# Iron                0
# Vitamin D           0
# Health_Status       0
# dtype: int64

# %%
x['Weight']=x['Weight'].fillna(x['Weight'].mean())
x['Blood Pressure']=x['Blood Pressure'].fillna(x['Blood Pressure'].mean())
x['Cholesterol']=x['Cholesterol'].fillna(x['Cholesterol'].mean())
x['Glucose']=x['Glucose'].fillna(x['Glucose'].mean())
x.isna().sum()
# Out:
# Age               0
# Weight            0
# Height            0
# BMI               0
# Blood Pressure    0
# Heart Rate        0
# Cholesterol       0
# Glucose           0
# Calcium           0
# Iron              0
# Vitamin D         0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
#        Age  Weight  Height   BMI  Blood Pressure  Heart Rate  Cholesterol  \
# 1334  46.0    66.6   181.1  31.1       94.000000        98.0        141.3
# 4768  42.0    55.8   158.7  27.3      110.000000        89.0        240.6
# 65    53.0    96.5   178.5  21.1      102.000000        71.0        194.5
# 177   45.0    79.6   174.5  34.3      123.943368        77.0        151.4
# 4489  63.0    81.9   182.1  26.5      122.000000        89.0        171.7
# ...    ...     ...     ...   ...             ...         ...          ...
# 2895  36.0    76.2   151.5  34.7      112.000000       108.0        259.4
# 2763  35.0    67.4   161.2  21.9      120.000000        74.0        130.4
# 905   34.0    63.4   156.6  33.6       98.000000       104.0        124.6
# 3980  39.0    68.8   166.6  27.4      130.000000        91.0        183.1
# 235   18.0    89.2   155.0  26.4       94.000000       108.0        257.2
#
#       Glucose  Calcium   Iron  Vitamin D
# 1334     75.1     10.2  125.6       49.1
# 4768     80.1     10.1  130.9       46.0
# 65      115.4     10.4  152.9       24.1
# 177     111.0      9.2  151.9       38.9
# 4489    104.0      8.2  138.1       21.4
# ...       ...      ...    ...        ...
# 2895    150.7     10.9  137.7       25.3
# 2763     98.4      8.7  105.5       47.0
# 905     129.7     10.6  113.5       30.3
# 3980    138.4      8.9  117.2       47.3
# 235     109.0      8.7   61.1       23.6
#
# [3500 rows x 11 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(criterion='entropy')
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['High BP', 'High BP', 'Obesity', ..., 'Obesity', 'Obesity',
#        'High BP'], shape=(1500,), dtype=object)

# %%
from sklearn import tree
plt.figure(figsize=(10,10))
tree.plot_tree(model,feature_names=['Age','Weight','Height','BMI','Blood Pressure','Heart Rate','Cholesterol','Glucose','Calcium','Iron','Vitamin D'],class_names=['Vitamin D Deficiency','Iron Deficiency','High BP','Obesity','Healthy'],filled=True)
# Out:
# [Text(0.599616930010893, 0.9827586206896551, 'Glucose <= 177.75\nentropy = 2.321\nsamples = 3500\nvalue = [729, 671, 713, 725, 662]\nclass = Vitamin D Deficiency'),
#  Text(0.2127805836283368, 0.9482758620689655, 'Height <= 150.45\nentropy = 2.32\nsamples = 3430\nvalue = [721, 652, 700, 718, 639]\nclass = Vitamin D Deficiency'),
#  Text(0.4061987568196149, 0.9655172413793103, 'True  '),
#  Text(0.006768325846544326, 0.9137931034482759, 'Glucose <= 113.15\nentropy = 2.062\nsamples = 41\nvalue = [9, 18, 4, 4, 6]\nclass = Iron Deficiency'),
#  Text(0.0025784098463026007, 0.8793103448275862, 'Weight <= 75.95\nentropy = 2.182\nsamples = 14\nvalue = [1, 4, 4, 3, 2]\nclass = Iron Deficiency'),
#  Text(0.0012892049231513004, 0.8448275862068966, 'Glucose <= 107.35\nentropy = 1.252\nsamples = 6\nvalue = [0, 0, 4, 1, 1]\nclass = High BP'),
#  Text(0.0006446024615756502, 0.8103448275862069, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0]\nclass = High BP'),
#  Text(0.0019338073847269504, 0.8103448275862069, 'BMI <= 28.85\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 1, 1]\nclass = Obesity'),
#  Text(0.0012892049231513004, 0.7758620689655172, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Healthy'),
#  Text(0.0025784098463026007, 0.7758620689655172, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.003867614769453901, 0.8448275862068966, 'Calcium <= 8.15\nentropy = 1.75\nsamples = 8\nvalue = [1, 4, 0, 2, 1]\nclass = Iron Deficiency'),
#  Text(0.0032230123078782506, 0.8103448275862069, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]\nclass = Obesity'),
#  Text(0.004512217231029551, 0.8103448275862069, 'Glucose <= 82.9\nentropy = 1.252\nsamples = 6\nvalue = [1, 4, 0, 0, 1]\nclass = Iron Deficiency'),
#  Text(0.003867614769453901, 0.7758620689655172, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Healthy'),
#  Text(0.0051568196926052015, 0.7758620689655172, 'Vitamin D <= 33.6\nentropy = 0.722\nsamples = 5\nvalue = [1, 4, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.004512217231029551, 0.7413793103448276, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.005801422154180851, 0.7413793103448276, 'Iron <= 93.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.0051568196926052015, 0.7068965517241379, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.006446024615756501, 0.7068965517241379, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.010958241846786053, 0.8793103448275862, 'Age <= 50.5\nentropy = 1.596\nsamples = 27\nvalue = [8, 14, 0, 1, 4]\nclass = Iron Deficiency'),
#  Text(0.008379832000483452, 0.8448275862068966, 'Heart Rate <= 86.0\nentropy = 1.135\nsamples = 18\nvalue = [5, 12, 0, 1, 0]\nclass = Iron Deficiency'),
#  Text(0.007735229538907802, 0.8103448275862069, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.009024434462059102, 0.8103448275862069, 'Blood Pressure <= 108.5\nentropy = 1.349\nsamples = 11\nvalue = [5, 5, 0, 1, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.007735229538907802, 0.7758620689655172, 'Calcium <= 10.8\nentropy = 0.811\nsamples = 4\nvalue = [0, 3, 0, 1, 0]\nclass = Iron Deficiency'),
#  Text(0.0070906270773321515, 0.7413793103448276, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.008379832000483452, 0.7413793103448276, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.010313639385210403, 0.7758620689655172, 'Glucose <= 143.65\nentropy = 0.863\nsamples = 7\nvalue = [5, 2, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.009669036923634753, 0.7413793103448276, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.010958241846786053, 0.7413793103448276, 'Calcium <= 9.9\nentropy = 0.918\nsamples = 3\nvalue = [1, 2, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.010313639385210403, 0.7068965517241379, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.011602844308361702, 0.7068965517241379, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.013536651693088653, 0.8448275862068966, 'Weight <= 81.95\nentropy = 1.53\nsamples = 9\nvalue = [3, 2, 0, 0, 4]\nclass = Healthy'),
#  Text(0.012247446769937352, 0.8103448275862069, 'BMI <= 30.0\nentropy = 0.722\nsamples = 5\nvalue = [0, 1, 0, 0, 4]\nclass = Healthy'),
#  Text(0.011602844308361702, 0.7758620689655172, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]\nclass = Healthy'),
#  Text(0.012892049231513002, 0.7758620689655172, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.014825856616239953, 0.8103448275862069, 'Glucose <= 158.95\nentropy = 0.811\nsamples = 4\nvalue = [3, 1, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.014181254154664303, 0.7758620689655172, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.015470459077815604, 0.7758620689655172, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.41879284141012924, 0.9137931034482759, 'Height <= 152.55\nentropy = 2.32\nsamples = 3389\nvalue = [712, 634, 696, 714, 633]\nclass = Obesity'),
#  Text(0.05038222911588744, 0.8793103448275862, 'Height <= 152.15\nentropy = 2.262\nsamples = 171\nvalue = [20, 31, 47, 30, 43]\nclass = High BP'),
#  Text(0.03952722438208811, 0.8448275862068966, 'Iron <= 147.85\nentropy = 2.274\nsamples = 145\nvalue = [19, 23, 40, 30, 33]\nclass = High BP'),
#  Text(0.02587474568418508, 0.8103448275862069, 'Calcium <= 9.25\nentropy = 2.258\nsamples = 132\nvalue = [19, 18, 40, 26, 29]\nclass = High BP'),
#  Text(0.018693471385693855, 0.7758620689655172, 'Age <= 34.0\nentropy = 2.081\nsamples = 49\nvalue = [11.0, 2.0, 17.0, 6.0, 13.0]\nclass = High BP'),
#  Text(0.014503555385452128, 0.7413793103448276, 'Glucose <= 120.103\nentropy = 2.213\nsamples = 18\nvalue = [5, 2, 5, 4, 2]\nclass = Vitamin D Deficiency'),
#  Text(0.012892049231513002, 0.7068965517241379, 'Cholesterol <= 186.3\nentropy = 1.561\nsamples = 8\nvalue = [3, 2, 3, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.012247446769937352, 0.6724137931034483, 'Age <= 30.0\nentropy = 1.0\nsamples = 6\nvalue = [3, 0, 3, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.011602844308361702, 0.6379310344827587, 'Heart Rate <= 73.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 0, 3, 0, 0]\nclass = High BP'),
#  Text(0.010958241846786053, 0.603448275862069, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.012247446769937352, 0.603448275862069, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0]\nclass = High BP'),
#  Text(0.012892049231513002, 0.6379310344827587, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.013536651693088653, 0.6724137931034483, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.016115061539391254, 0.7068965517241379, 'Calcium <= 9.1\nentropy = 1.922\nsamples = 10\nvalue = [2, 0, 2, 4, 2]\nclass = Obesity'),
#  Text(0.015470459077815604, 0.6724137931034483, 'Heart Rate <= 60.5\nentropy = 1.5\nsamples = 8\nvalue = [0, 0, 2, 4, 2]\nclass = Obesity'),
#  Text(0.014181254154664303, 0.6379310344827587, 'Cholesterol <= 140.55\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 1, 0, 2]\nclass = Healthy'),
#  Text(0.013536651693088653, 0.603448275862069, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.014825856616239953, 0.603448275862069, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]\nclass = Healthy'),
#  Text(0.016759664000966904, 0.6379310344827587, 'Glucose <= 170.55\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 1, 4, 0]\nclass = Obesity'),
#  Text(0.016115061539391254, 0.603448275862069, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0]\nclass = Obesity'),
#  Text(0.017404266462542554, 0.603448275862069, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.016759664000966904, 0.6724137931034483, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.02288338738593558, 0.7413793103448276, 'Blood Pressure <= 142.5\nentropy = 1.774\nsamples = 31\nvalue = [6, 0, 12, 2, 11]\nclass = High BP'),
#  Text(0.021271881231996456, 0.7068965517241379, 'Heart Rate <= 74.5\nentropy = 1.829\nsamples = 25\nvalue = [6.0, 0.0, 7.0, 2.0, 10.0]\nclass = Healthy'),
#  Text(0.019982676308845156, 0.6724137931034483, 'Weight <= 57.85\nentropy = 1.299\nsamples = 8\nvalue = [1, 0, 0, 2, 5]\nclass = Healthy'),
#  Text(0.019338073847269505, 0.6379310344827587, 'BMI <= 28.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 0, 0, 2, 0]\nclass = Obesity'),
#  Text(0.018693471385693855, 0.603448275862069, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]\nclass = Obesity'),
#  Text(0.019982676308845156, 0.603448275862069, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.020627278770420806, 0.6379310344827587, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5]\nclass = Healthy'),
#  Text(0.022561086155147753, 0.6724137931034483, 'Heart Rate <= 78.0\nentropy = 1.566\nsamples = 17\nvalue = [5, 0, 7, 0, 5]\nclass = High BP'),
#  Text(0.021916483693572106, 0.6379310344827587, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.023205688616723404, 0.6379310344827587, 'Blood Pressure <= 122.972\nentropy = 1.506\nsamples = 15\nvalue = [3, 0, 7, 0, 5]\nclass = High BP'),
#  Text(0.021916483693572106, 0.603448275862069, 'BMI <= 24.45\nentropy = 0.811\nsamples = 8\nvalue = [0, 0, 6, 0, 2]\nclass = High BP'),
#  Text(0.021271881231996456, 0.5689655172413793, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0]\nclass = High BP'),
#  Text(0.022561086155147753, 0.5689655172413793, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]\nclass = Healthy'),
#  Text(0.024494893539874704, 0.603448275862069, 'Vitamin D <= 51.5\nentropy = 1.449\nsamples = 7\nvalue = [3, 0, 1, 0, 3]\nclass = Vitamin D Deficiency'),
#  Text(0.023850291078299054, 0.5689655172413793, 'Calcium <= 8.3\nentropy = 1.0\nsamples = 6\nvalue = [3, 0, 0, 0, 3]\nclass = Vitamin D Deficiency'),
#  Text(0.023205688616723404, 0.5344827586206896, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]\nclass = Healthy'),
#  Text(0.024494893539874704, 0.5344827586206896, 'Blood Pressure <= 126.472\nentropy = 0.811\nsamples = 4\nvalue = [3, 0, 0, 0, 1]\nclass = Vitamin D Deficiency'),
#  Text(0.023850291078299054, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Healthy'),
#  Text(0.025139496001450354, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.025139496001450354, 0.5689655172413793, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.024494893539874704, 0.7068965517241379, 'Vitamin D <= 51.6\nentropy = 0.65\nsamples = 6\nvalue = [0, 0, 5, 0, 1]\nclass = High BP'),
#  Text(0.023850291078299054, 0.6724137931034483, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0]\nclass = High BP'),
#  Text(0.025139496001450354, 0.6724137931034483, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Healthy'),
#  Text(0.03305601998267631, 0.7758620689655172, 'Heart Rate <= 62.5\nentropy = 2.249\nsamples = 83\nvalue = [8, 16, 23, 20, 16]\nclass = High BP'),
#  Text(0.027717905847752956, 0.7413793103448276, 'Age <= 47.5\nentropy = 1.352\nsamples = 9\nvalue = [0, 3, 1, 0, 5]\nclass = Healthy'),
#  Text(0.027073303386177305, 0.7068965517241379, 'Glucose <= 78.85\nentropy = 0.65\nsamples = 6\nvalue = [0, 0, 1, 0, 5]\nclass = Healthy'),
#  Text(0.026428700924601655, 0.6724137931034483, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.027717905847752956, 0.6724137931034483, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5]\nclass = Healthy'),
#  Text(0.028362508309328606, 0.7068965517241379, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.03839413411759966, 0.7413793103448276, 'Glucose <= 107.7\nentropy = 2.227\nsamples = 74\nvalue = [8, 13, 22, 20, 11]\nclass = High BP'),
#  Text(0.030296315694055557, 0.7068965517241379, 'Heart Rate <= 88.0\nentropy = 1.459\nsamples = 18\nvalue = [0, 3, 6, 9, 0]\nclass = Obesity'),
#  Text(0.029007110770904256, 0.6724137931034483, 'Iron <= 129.2\nentropy = 0.764\nsamples = 9\nvalue = [0, 2, 0, 7, 0]\nclass = Obesity'),
#  Text(0.028362508309328606, 0.6379310344827587, 'Heart Rate <= 83.5\nentropy = 0.544\nsamples = 8\nvalue = [0, 1, 0, 7, 0]\nclass = Obesity'),
#  Text(0.027717905847752956, 0.603448275862069, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0]\nclass = Obesity'),
#  Text(0.029007110770904256, 0.603448275862069, 'Iron <= 54.1\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 0, 1, 0]\nclass = Iron Deficiency'),
#  Text(0.028362508309328606, 0.5689655172413793, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.029651713232479907, 0.5689655172413793, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.029651713232479907, 0.6379310344827587, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.031585520617206854, 0.6724137931034483, 'Calcium <= 10.3\nentropy = 1.224\nsamples = 9\nvalue = [0, 1, 6, 2, 0]\nclass = High BP'),
#  Text(0.030940918155631207, 0.6379310344827587, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0]\nclass = High BP'),
#  Text(0.03223012307878251, 0.6379310344827587, 'Vitamin D <= 18.0\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 0, 2, 0]\nclass = Obesity'),
#  Text(0.031585520617206854, 0.603448275862069, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.032874725540358155, 0.603448275862069, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]\nclass = Obesity'),
#  Text(0.046491952541143765, 0.7068965517241379, 'Height <= 151.75\nentropy = 2.284\nsamples = 56\nvalue = [8, 10, 16, 11, 11]\nclass = High BP'),
#  Text(0.0410934069254477, 0.6724137931034483, 'Blood Pressure <= 142.5\nentropy = 2.216\nsamples = 40\nvalue = [6, 7, 12, 11, 4]\nclass = High BP'),
#  Text(0.03642003907902423, 0.6379310344827587, 'BMI <= 20.05\nentropy = 2.039\nsamples = 30\nvalue = [2, 4, 10, 11, 3]\nclass = Obesity'),
#  Text(0.034163930463509455, 0.603448275862069, 'Height <= 151.3\nentropy = 1.0\nsamples = 4\nvalue = [2, 0, 2, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.03351932800193381, 0.5689655172413793, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.03480853292508511, 0.5689655172413793, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]\nclass = High BP'),
#  Text(0.03867614769453901, 0.603448275862069, 'Iron <= 62.2\nentropy = 1.823\nsamples = 26\nvalue = [0, 4, 8, 11, 3]\nclass = Obesity'),
#  Text(0.03609773784823641, 0.5689655172413793, 'Vitamin D <= 51.9\nentropy = 1.753\nsamples = 9\nvalue = [0, 4, 3, 1, 1]\nclass = Iron Deficiency'),
#  Text(0.03480853292508511, 0.5344827586206896, 'Vitamin D <= 31.95\nentropy = 0.985\nsamples = 7\nvalue = [0, 4, 3, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.034163930463509455, 0.5, 'Glucose <= 117.8\nentropy = 0.811\nsamples = 4\nvalue = [0, 1, 3, 0, 0]\nclass = High BP'),
#  Text(0.03351932800193381, 0.46551724137931033, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.03480853292508511, 0.46551724137931033, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0]\nclass = High BP'),
#  Text(0.035453135386660756, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.03738694277138771, 0.5344827586206896, 'Blood Pressure <= 130.5\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 0, 1, 1]\nclass = Obesity'),
#  Text(0.036742340309812056, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Healthy'),
#  Text(0.03803154523296336, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.04125455754084161, 0.5689655172413793, 'Age <= 56.0\nentropy = 1.333\nsamples = 17\nvalue = [0, 0, 5, 10, 2]\nclass = Obesity'),
#  Text(0.03996535261769031, 0.5344827586206896, 'Heart Rate <= 103.0\nentropy = 0.811\nsamples = 12\nvalue = [0, 0, 3, 9, 0]\nclass = Obesity'),
#  Text(0.03932075015611466, 0.5, 'Blood Pressure <= 93.0\nentropy = 0.469\nsamples = 10\nvalue = [0, 0, 1, 9, 0]\nclass = Obesity'),
#  Text(0.03867614769453901, 0.46551724137931033, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.03996535261769031, 0.46551724137931033, 'entropy = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0]\nclass = Obesity'),
#  Text(0.04060995507926596, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]\nclass = High BP'),
#  Text(0.04254376246399291, 0.5344827586206896, 'Heart Rate <= 93.5\nentropy = 1.522\nsamples = 5\nvalue = [0, 0, 2, 1, 2]\nclass = High BP'),
#  Text(0.04189916000241726, 0.5, 'BMI <= 33.05\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 2, 1, 0]\nclass = High BP'),
#  Text(0.04125455754084161, 0.46551724137931033, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]\nclass = High BP'),
#  Text(0.04254376246399291, 0.46551724137931033, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.04318836492556856, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]\nclass = Healthy'),
#  Text(0.04576677477187116, 0.6379310344827587, 'Vitamin D <= 36.2\nentropy = 1.846\nsamples = 10\nvalue = [4, 3, 2, 0, 1]\nclass = Vitamin D Deficiency'),
#  Text(0.04383296738714421, 0.603448275862069, 'Glucose <= 136.65\nentropy = 1.5\nsamples = 4\nvalue = [1, 0, 2, 0, 1]\nclass = High BP'),
#  Text(0.04318836492556856, 0.5689655172413793, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]\nclass = High BP'),
#  Text(0.04447756984871986, 0.5689655172413793, 'Glucose <= 152.1\nentropy = 1.0\nsamples = 2\nvalue = [1, 0, 0, 0, 1]\nclass = Vitamin D Deficiency'),
#  Text(0.04383296738714421, 0.5344827586206896, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Healthy'),
#  Text(0.04512217231029551, 0.5344827586206896, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.04770058215659811, 0.603448275862069, 'Vitamin D <= 51.0\nentropy = 1.0\nsamples = 6\nvalue = [3, 3, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.04705597969502246, 0.5689655172413793, 'Age <= 24.0\nentropy = 0.811\nsamples = 4\nvalue = [3, 1, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.04641137723344681, 0.5344827586206896, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.04770058215659811, 0.5344827586206896, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.04834518461817376, 0.5689655172413793, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.05189049815683983, 0.6724137931034483, 'Iron <= 81.65\nentropy = 1.85\nsamples = 16\nvalue = [2, 3, 4, 0, 7]\nclass = Healthy'),
#  Text(0.04963438954132506, 0.6379310344827587, 'Age <= 49.5\nentropy = 0.985\nsamples = 7\nvalue = [0, 3, 0, 0, 4]\nclass = Healthy'),
#  Text(0.04898978707974941, 0.603448275862069, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]\nclass = Healthy'),
#  Text(0.05027899200290071, 0.603448275862069, 'Blood Pressure <= 136.0\nentropy = 0.811\nsamples = 4\nvalue = [0, 3, 0, 0, 1]\nclass = Iron Deficiency'),
#  Text(0.04963438954132506, 0.5689655172413793, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.05092359446447636, 0.5689655172413793, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Healthy'),
#  Text(0.05414660677235461, 0.6379310344827587, 'Weight <= 84.9\nentropy = 1.53\nsamples = 9\nvalue = [2, 0, 4, 0, 3]\nclass = High BP'),
#  Text(0.05285740184920331, 0.603448275862069, 'Iron <= 95.55\nentropy = 1.0\nsamples = 6\nvalue = [0, 0, 3, 0, 3]\nclass = High BP'),
#  Text(0.05221279938762766, 0.5689655172413793, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]\nclass = High BP'),
#  Text(0.053502004310778964, 0.5689655172413793, 'Weight <= 49.3\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 1, 0, 3]\nclass = Healthy'),
#  Text(0.05285740184920331, 0.5344827586206896, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.05414660677235461, 0.5344827586206896, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]\nclass = Healthy'),
#  Text(0.05543581169550591, 0.603448275862069, 'Age <= 50.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 0, 1, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.054791209233930264, 0.5689655172413793, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.056080414157081565, 0.5689655172413793, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.053179703079991134, 0.8103448275862069, 'Glucose <= 145.0\nentropy = 1.577\nsamples = 13\nvalue = [0, 5, 0, 4, 4]\nclass = Iron Deficiency'),
#  Text(0.05253510061841549, 0.7758620689655172, 'Age <= 50.5\nentropy = 1.361\nsamples = 10\nvalue = [0, 5, 0, 1, 4]\nclass = Iron Deficiency'),
#  Text(0.05189049815683983, 0.7413793103448276, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.053179703079991134, 0.7413793103448276, 'Heart Rate <= 87.5\nentropy = 1.252\nsamples = 6\nvalue = [0, 1, 0, 1, 4]\nclass = Healthy'),
#  Text(0.05253510061841549, 0.7068965517241379, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]\nclass = Healthy'),
#  Text(0.05382430554156679, 0.7068965517241379, 'Iron <= 149.6\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 0, 1, 0]\nclass = Iron Deficiency'),
#  Text(0.053179703079991134, 0.6724137931034483, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.054468908003142434, 0.6724137931034483, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.05382430554156679, 0.7758620689655172, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0]\nclass = Obesity'),
#  Text(0.06123723384968676, 0.8448275862068966, 'Height <= 152.45\nentropy = 1.744\nsamples = 26\nvalue = [1, 8, 7, 0, 10]\nclass = Healthy'),
#  Text(0.05994802892653546, 0.8103448275862069, 'Glucose <= 168.75\nentropy = 1.575\nsamples = 21\nvalue = [0, 8, 7, 0, 6]\nclass = Iron Deficiency'),
#  Text(0.05930342646495981, 0.7758620689655172, 'BMI <= 27.95\nentropy = 1.481\nsamples = 18\nvalue = [0, 8, 7, 0, 3]\nclass = Iron Deficiency'),
#  Text(0.05769192031102069, 0.7413793103448276, 'BMI <= 24.45\nentropy = 1.485\nsamples = 10\nvalue = [0, 5, 2, 0, 3]\nclass = Iron Deficiency'),
#  Text(0.05640271538786939, 0.7068965517241379, 'Heart Rate <= 89.0\nentropy = 0.971\nsamples = 5\nvalue = [0, 3, 2, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.055758112926293735, 0.6724137931034483, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]\nclass = High BP'),
#  Text(0.057047317849445035, 0.6724137931034483, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.05898112523417199, 0.7068965517241379, 'Vitamin D <= 23.1\nentropy = 0.971\nsamples = 5\nvalue = [0, 2, 0, 0, 3]\nclass = Healthy'),
#  Text(0.058336522772596336, 0.6724137931034483, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]\nclass = Healthy'),
#  Text(0.059625727695747636, 0.6724137931034483, 'Weight <= 71.25\nentropy = 0.918\nsamples = 3\nvalue = [0, 2, 0, 0, 1]\nclass = Iron Deficiency'),
#  Text(0.05898112523417199, 0.6379310344827587, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Healthy'),
#  Text(0.06027033015732329, 0.6379310344827587, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.06091493261889894, 0.7413793103448276, 'Blood Pressure <= 137.0\nentropy = 0.954\nsamples = 8\nvalue = [0, 3, 5, 0, 0]\nclass = High BP'),
#  Text(0.06027033015732329, 0.7068965517241379, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0]\nclass = High BP'),
#  Text(0.06155953508047459, 0.7068965517241379, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.060592631388111114, 0.7758620689655172, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]\nclass = Healthy'),
#  Text(0.06252643877283806, 0.8103448275862069, 'Age <= 56.5\nentropy = 0.722\nsamples = 5\nvalue = [1, 0, 0, 0, 4]\nclass = Healthy'),
#  Text(0.061881836311262414, 0.7758620689655172, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]\nclass = Healthy'),
#  Text(0.06317104123441371, 0.7758620689655172, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.7872034537043711, 0.8793103448275862, 'Glucose <= 168.65\nentropy = 2.319\nsamples = 3218\nvalue = [692, 603, 649, 684, 590]\nclass = Vitamin D Deficiency'),
#  Text(0.6270206948510805, 0.8448275862068966, 'Heart Rate <= 93.5\nentropy = 2.32\nsamples = 2976\nvalue = [644, 565, 594, 611, 562]\nclass = Vitamin D Deficiency'),
#  Text(0.41293723415656536, 0.8103448275862069, 'Glucose <= 129.25\nentropy = 2.321\nsamples = 2059\nvalue = [407, 393, 429, 421, 409]\nclass = High BP'),
#  Text(0.2796997023592198, 0.7758620689655172, 'BMI <= 25.15\nentropy = 2.316\nsamples = 1316\nvalue = [268, 230, 303, 263, 252]\nclass = High BP'),
#  Text(0.18195749683993714, 0.7413793103448276, 'Cholesterol <= 256.95\nentropy = 2.307\nsamples = 524\nvalue = [121, 86, 106, 89, 122]\nclass = Healthy'),
#  Text(0.140177508032351, 0.7068965517241379, 'Weight <= 56.75\nentropy = 2.302\nsamples = 512\nvalue = [121, 83, 101, 85, 122]\nclass = Healthy'),
#  Text(0.07810768889873698, 0.6724137931034483, 'Glucose <= 115.65\nentropy = 2.198\nsamples = 105\nvalue = [34.0, 14.0, 29.0, 12.0, 16.0]\nclass = Vitamin D Deficiency'),
#  Text(0.0717724553310638, 0.6379310344827587, 'BMI <= 24.05\nentropy = 2.201\nsamples = 69\nvalue = [20.0, 11.0, 17.0, 5.0, 16.0]\nclass = Vitamin D Deficiency'),
#  Text(0.06296960296517132, 0.603448275862069, 'Height <= 158.4\nentropy = 2.165\nsamples = 57\nvalue = [12, 10, 17, 3, 15]\nclass = High BP'),
#  Text(0.057369619080232866, 0.5689655172413793, 'Blood Pressure <= 141.5\nentropy = 1.918\nsamples = 6\nvalue = [2, 1, 1, 2, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.056080414157081565, 0.5344827586206896, 'Age <= 54.5\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 0, 2, 0]\nclass = Obesity'),
#  Text(0.05543581169550591, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]\nclass = Obesity'),
#  Text(0.05672501661865721, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.058658824003384166, 0.5344827586206896, 'Glucose <= 95.85\nentropy = 0.918\nsamples = 3\nvalue = [2, 0, 1, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.05801422154180851, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.05930342646495981, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.06856958685010979, 0.5689655172413793, 'Height <= 172.95\nentropy = 2.058\nsamples = 51\nvalue = [10, 9, 16, 1, 15]\nclass = High BP'),
#  Text(0.0630098906190198, 0.5344827586206896, 'Vitamin D <= 18.4\nentropy = 1.665\nsamples = 23\nvalue = [2, 2, 10, 0, 9]\nclass = High BP'),
#  Text(0.060592631388111114, 0.5, 'Height <= 162.0\nentropy = 1.5\nsamples = 4\nvalue = [0, 2, 1, 0, 1]\nclass = Iron Deficiency'),
#  Text(0.05994802892653546, 0.46551724137931033, 'Weight <= 49.8\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 0, 1]\nclass = High BP'),
#  Text(0.05930342646495981, 0.43103448275862066, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.060592631388111114, 0.43103448275862066, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Healthy'),
#  Text(0.06123723384968676, 0.46551724137931033, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.06542714984992849, 0.5, 'Height <= 165.8\nentropy = 1.378\nsamples = 19\nvalue = [2, 0, 9, 0, 8]\nclass = High BP'),
#  Text(0.06317104123441371, 0.46551724137931033, 'Weight <= 52.9\nentropy = 1.371\nsamples = 10\nvalue = [2, 0, 2, 0, 6]\nclass = Healthy'),
#  Text(0.061881836311262414, 0.43103448275862066, 'Iron <= 104.15\nentropy = 0.863\nsamples = 7\nvalue = [2, 0, 0, 0, 5]\nclass = Healthy'),
#  Text(0.06123723384968676, 0.39655172413793105, 'Glucose <= 84.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 0, 0, 0, 1]\nclass = Vitamin D Deficiency'),
#  Text(0.060592631388111114, 0.3620689655172414, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Healthy'),
#  Text(0.061881836311262414, 0.3620689655172414, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.06252643877283806, 0.39655172413793105, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]\nclass = Healthy'),
#  Text(0.06446024615756502, 0.43103448275862066, 'Weight <= 54.75\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 2, 0, 1]\nclass = High BP'),
#  Text(0.06381564369598937, 0.39655172413793105, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]\nclass = High BP'),
#  Text(0.06510484861914066, 0.39655172413793105, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Healthy'),
#  Text(0.06768325846544326, 0.46551724137931033, 'Blood Pressure <= 108.5\nentropy = 0.764\nsamples = 9\nvalue = [0, 0, 7, 0, 2]\nclass = High BP'),
#  Text(0.06703865600386762, 0.43103448275862066, 'Iron <= 95.0\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 1, 0, 2]\nclass = Healthy'),
#  Text(0.06639405354229197, 0.39655172413793105, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]\nclass = Healthy'),
#  Text(0.06768325846544326, 0.39655172413793105, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.06832786092701891, 0.43103448275862066, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0]\nclass = High BP'),
#  Text(0.07412928308119976, 0.5344827586206896, 'Age <= 43.5\nentropy = 2.141\nsamples = 28\nvalue = [8, 7, 6, 1, 6]\nclass = Vitamin D Deficiency'),
#  Text(0.07155087323489717, 0.5, 'Cholesterol <= 140.4\nentropy = 1.555\nsamples = 12\nvalue = [3, 5, 4, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.07026166831174586, 0.46551724137931033, 'Iron <= 92.45\nentropy = 0.722\nsamples = 5\nvalue = [0, 1, 4, 0, 0]\nclass = High BP'),
#  Text(0.06961706585017022, 0.43103448275862066, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0]\nclass = High BP'),
#  Text(0.07090627077332151, 0.43103448275862066, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.07284007815804847, 0.46551724137931033, 'Age <= 21.5\nentropy = 0.985\nsamples = 7\nvalue = [3, 4, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.07219547569647282, 0.43103448275862066, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.07348468061962411, 0.43103448275862066, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.07670769292750236, 0.5, 'BMI <= 20.15\nentropy = 2.055\nsamples = 16\nvalue = [5, 2, 2, 1, 6]\nclass = Healthy'),
#  Text(0.07541848800435107, 0.46551724137931033, 'Glucose <= 78.9\nentropy = 1.436\nsamples = 9\nvalue = [5, 2, 0, 0, 2]\nclass = Vitamin D Deficiency'),
#  Text(0.07477388554277542, 0.43103448275862066, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.07606309046592671, 0.43103448275862066, 'Age <= 49.0\nentropy = 0.863\nsamples = 7\nvalue = [5, 0, 0, 0, 2]\nclass = Vitamin D Deficiency'),
#  Text(0.07541848800435107, 0.39655172413793105, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]\nclass = Healthy'),
#  Text(0.07670769292750236, 0.39655172413793105, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.07799689785065367, 0.46551724137931033, 'Weight <= 52.25\nentropy = 1.379\nsamples = 7\nvalue = [0, 0, 2, 1, 4]\nclass = Healthy'),
#  Text(0.07735229538907802, 0.43103448275862066, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]\nclass = Healthy'),
#  Text(0.07864150031222931, 0.43103448275862066, 'Vitamin D <= 26.2\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 2, 1, 0]\nclass = High BP'),
#  Text(0.07799689785065367, 0.39655172413793105, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.07928610277380496, 0.39655172413793105, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]\nclass = High BP'),
#  Text(0.08057530769695627, 0.603448275862069, 'Vitamin D <= 34.95\nentropy = 1.418\nsamples = 12\nvalue = [8, 1, 0, 2, 1]\nclass = Vitamin D Deficiency'),
#  Text(0.07993070523538062, 0.5689655172413793, 'Heart Rate <= 75.5\nentropy = 1.922\nsamples = 5\nvalue = [1, 1, 0, 2, 1]\nclass = Obesity'),
#  Text(0.07864150031222931, 0.5344827586206896, 'Cholesterol <= 208.75\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 0, 0, 1]\nclass = Iron Deficiency'),
#  Text(0.07799689785065367, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Healthy'),
#  Text(0.07928610277380496, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.08121991015853192, 0.5344827586206896, 'Height <= 180.7\nentropy = 0.918\nsamples = 3\nvalue = [1, 0, 0, 2, 0]\nclass = Obesity'),
#  Text(0.08057530769695627, 0.5, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]\nclass = Obesity'),
#  Text(0.08186451262010756, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.08121991015853192, 0.5689655172413793, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.08444292246641016, 0.6379310344827587, 'Cholesterol <= 174.85\nentropy = 1.816\nsamples = 36\nvalue = [14, 3, 12, 7, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.08315371754325887, 0.603448275862069, 'BMI <= 23.15\nentropy = 0.971\nsamples = 10\nvalue = [4, 0, 6, 0, 0]\nclass = High BP'),
#  Text(0.08250911508168322, 0.5689655172413793, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0]\nclass = High BP'),
#  Text(0.08379832000483452, 0.5689655172413793, 'Vitamin D <= 37.3\nentropy = 0.722\nsamples = 5\nvalue = [4, 0, 1, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.08315371754325887, 0.5344827586206896, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.08444292246641016, 0.5344827586206896, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.08573212738956147, 0.603448275862069, 'Cholesterol <= 183.05\nentropy = 1.888\nsamples = 26\nvalue = [10, 3, 6, 7, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.08508752492798582, 0.5689655172413793, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.08637672985113712, 0.5689655172413793, 'Vitamin D <= 19.4\nentropy = 1.736\nsamples = 24\nvalue = [10, 1, 6, 7, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.08573212738956147, 0.5344827586206896, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0]\nclass = High BP'),
#  Text(0.08702133231271277, 0.5344827586206896, 'Iron <= 54.2\nentropy = 1.648\nsamples = 21\nvalue = [10, 1, 3, 7, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.08540982615877364, 0.5, 'Age <= 42.5\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 1, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.084765223697198, 0.46551724137931033, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.08605442862034929, 0.46551724137931033, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.08863283846665189, 0.5, 'Vitamin D <= 35.15\nentropy = 1.36\nsamples = 19\nvalue = [10, 0, 2, 7, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.0873436335435006, 0.46551724137931033, 'BMI <= 20.95\nentropy = 0.845\nsamples = 11\nvalue = [8, 0, 0, 3, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.08669903108192495, 0.43103448275862066, 'Age <= 51.5\nentropy = 1.0\nsamples = 6\nvalue = [3, 0, 0, 3, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.08605442862034929, 0.39655172413793105, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0]\nclass = Obesity'),
#  Text(0.0873436335435006, 0.39655172413793105, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.08798823600507624, 0.43103448275862066, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.0899220433898032, 0.46551724137931033, 'Weight <= 49.9\nentropy = 1.5\nsamples = 8\nvalue = [2, 0, 2, 4, 0]\nclass = Obesity'),
#  Text(0.08927744092822755, 0.43103448275862066, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.09056664585137884, 0.43103448275862066, 'Iron <= 85.65\nentropy = 0.918\nsamples = 6\nvalue = [0, 0, 2, 4, 0]\nclass = Obesity'),
#  Text(0.0899220433898032, 0.39655172413793105, 'Iron <= 63.0\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 2, 1, 0]\nclass = High BP'),
#  Text(0.08927744092822755, 0.3620689655172414, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.09056664585137884, 0.3620689655172414, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]\nclass = High BP'),
#  Text(0.09121124831295449, 0.39655172413793105, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0]\nclass = Obesity'),
#  Text(0.202247327165965, 0.6724137931034483, 'Calcium <= 10.75\nentropy = 2.302\nsamples = 407\nvalue = [87, 69, 72, 73, 106]\nclass = Healthy'),
#  Text(0.18688089206937533, 0.6379310344827587, 'Weight <= 98.9\nentropy = 2.31\nsamples = 372\nvalue = [77, 69, 66, 68, 92]\nclass = Healthy'),
#  Text(0.16291634772274036, 0.603448275862069, 'Glucose <= 125.45\nentropy = 2.31\nsamples = 361\nvalue = [70.0, 67.0, 65.0, 68.0, 91.0]\nclass = Healthy'),
#  Text(0.12272248856837822, 0.5689655172413793, 'Age <= 25.5\nentropy = 2.31\nsamples = 342\nvalue = [62, 67, 63, 64, 86]\nclass = Healthy'),
#  Text(0.10192776423664968, 0.5344827586206896, 'BMI <= 24.15\nentropy = 2.152\nsamples = 40\nvalue = [7, 13, 9, 9, 2]\nclass = Iron Deficiency'),
#  Text(0.09717382108252925, 0.5, 'Cholesterol <= 175.75\nentropy = 2.009\nsamples = 29\nvalue = [2, 12, 8, 5, 2]\nclass = Iron Deficiency'),
#  Text(0.09443426062083275, 0.46551724137931033, 'Cholesterol <= 146.3\nentropy = 1.784\nsamples = 12\nvalue = [1, 4, 5, 0, 2]\nclass = High BP'),
#  Text(0.09314505569768144, 0.43103448275862066, 'BMI <= 23.35\nentropy = 0.722\nsamples = 5\nvalue = [1, 4, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.0925004532361058, 0.39655172413793105, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.09378965815925709, 0.39655172413793105, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.09572346554398405, 0.43103448275862066, 'Cholesterol <= 157.2\nentropy = 0.863\nsamples = 7\nvalue = [0, 0, 5, 0, 2]\nclass = High BP'),
#  Text(0.0950788630824084, 0.39655172413793105, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0]\nclass = High BP'),
#  Text(0.09636806800555969, 0.39655172413793105, 'Vitamin D <= 21.6\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 1, 0, 2]\nclass = Healthy'),
#  Text(0.09572346554398405, 0.3620689655172414, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.09701267046713534, 0.3620689655172414, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]\nclass = Healthy'),
#  Text(0.09991338154422577, 0.46551724137931033, 'Heart Rate <= 63.5\nentropy = 1.713\nsamples = 17\nvalue = [1, 8, 3, 5, 0]\nclass = Iron Deficiency'),
#  Text(0.09830187539028665, 0.43103448275862066, 'Glucose <= 113.75\nentropy = 0.811\nsamples = 4\nvalue = [0, 1, 3, 0, 0]\nclass = High BP'),
#  Text(0.097657272928711, 0.39655172413793105, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0]\nclass = High BP'),
#  Text(0.0989464778518623, 0.39655172413793105, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.1015248876981649, 0.43103448275862066, 'Glucose <= 91.5\nentropy = 1.296\nsamples = 13\nvalue = [1, 7, 0, 5, 0]\nclass = Iron Deficiency'),
#  Text(0.1002356827750136, 0.39655172413793105, 'Heart Rate <= 86.5\nentropy = 0.722\nsamples = 5\nvalue = [1, 4, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.09959108031343794, 0.3620689655172414, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.10088028523658925, 0.3620689655172414, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.1028140926213162, 0.39655172413793105, 'Age <= 22.5\nentropy = 0.954\nsamples = 8\nvalue = [0, 3, 0, 5, 0]\nclass = Obesity'),
#  Text(0.10216949015974054, 0.3620689655172414, 'BMI <= 22.8\nentropy = 0.811\nsamples = 4\nvalue = [0, 3, 0, 1, 0]\nclass = Iron Deficiency'),
#  Text(0.1015248876981649, 0.3275862068965517, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.1028140926213162, 0.3275862068965517, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.10345869508289185, 0.3620689655172414, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0]\nclass = Obesity'),
#  Text(0.1066817073907701, 0.5, 'Height <= 174.3\nentropy = 1.677\nsamples = 11\nvalue = [5, 1, 1, 4, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.1053925024676188, 0.46551724137931033, 'Iron <= 51.65\nentropy = 1.149\nsamples = 7\nvalue = [5, 1, 0, 1, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.10474790000604314, 0.43103448275862066, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.10603710492919445, 0.43103448275862066, 'BMI <= 24.35\nentropy = 0.65\nsamples = 6\nvalue = [5, 0, 0, 1, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.1053925024676188, 0.39655172413793105, 'Age <= 21.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 0, 0, 1, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.10474790000604314, 0.3620689655172414, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.10603710492919445, 0.3620689655172414, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.1066817073907701, 0.39655172413793105, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.1079709123139214, 0.46551724137931033, 'Age <= 20.5\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 1, 3, 0]\nclass = Obesity'),
#  Text(0.10732630985234574, 0.43103448275862066, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.10861551477549705, 0.43103448275862066, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0]\nclass = Obesity'),
#  Text(0.14351721290010677, 0.5344827586206896, 'Weight <= 62.15\nentropy = 2.297\nsamples = 302\nvalue = [55.0, 54.0, 54.0, 55.0, 84.0]\nclass = Healthy'),
#  Text(0.11425578631428399, 0.5, 'Heart Rate <= 76.5\nentropy = 2.047\nsamples = 33\nvalue = [11, 10, 1, 4, 7]\nclass = Vitamin D Deficiency'),
#  Text(0.11119392462179965, 0.46551724137931033, 'Iron <= 128.3\nentropy = 1.739\nsamples = 17\nvalue = [7, 6, 1, 3, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.10990471969864835, 0.43103448275862066, 'Blood Pressure <= 130.0\nentropy = 1.281\nsamples = 12\nvalue = [7, 4, 0, 1, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.1092601172370727, 0.39655172413793105, 'BMI <= 24.05\nentropy = 0.986\nsamples = 9\nvalue = [7, 1, 0, 1, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.10861551477549705, 0.3620689655172414, 'Vitamin D <= 52.5\nentropy = 0.544\nsamples = 8\nvalue = [7, 1, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.1079709123139214, 0.3275862068965517, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.1092601172370727, 0.3275862068965517, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.10990471969864835, 0.3620689655172414, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.110549322160224, 0.39655172413793105, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.11248312954495095, 0.43103448275862066, 'Age <= 44.5\nentropy = 1.522\nsamples = 5\nvalue = [0, 2, 1, 2, 0]\nclass = Iron Deficiency'),
#  Text(0.1118385270833753, 0.39655172413793105, 'Calcium <= 9.0\nentropy = 0.918\nsamples = 3\nvalue = [0, 2, 1, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.11119392462179965, 0.3620689655172414, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.11248312954495095, 0.3620689655172414, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.1131277320065266, 0.39655172413793105, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]\nclass = Obesity'),
#  Text(0.11731764800676833, 0.46551724137931033, 'Iron <= 103.15\nentropy = 1.772\nsamples = 16\nvalue = [4, 4, 0, 1, 7]\nclass = Healthy'),
#  Text(0.1157061418528292, 0.43103448275862066, 'Cholesterol <= 154.75\nentropy = 1.53\nsamples = 9\nvalue = [3, 4, 0, 0, 2]\nclass = Iron Deficiency'),
#  Text(0.1144169369296779, 0.39655172413793105, 'Blood Pressure <= 146.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.11377233446810225, 0.3620689655172414, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.11506153939125355, 0.3620689655172414, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.1169953467759805, 0.39655172413793105, 'Iron <= 66.25\nentropy = 0.971\nsamples = 5\nvalue = [0, 3, 0, 0, 2]\nclass = Iron Deficiency'),
#  Text(0.11635074431440486, 0.3620689655172414, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]\nclass = Healthy'),
#  Text(0.11763994923755615, 0.3620689655172414, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.11892915416070746, 0.43103448275862066, 'Blood Pressure <= 91.5\nentropy = 1.149\nsamples = 7\nvalue = [1, 0, 0, 1, 5]\nclass = Healthy'),
#  Text(0.1182845516991318, 0.39655172413793105, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.1195737566222831, 0.39655172413793105, 'Vitamin D <= 52.85\nentropy = 0.65\nsamples = 6\nvalue = [0, 0, 0, 1, 5]\nclass = Healthy'),
#  Text(0.11892915416070746, 0.3620689655172414, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5]\nclass = Healthy'),
#  Text(0.12021835908385875, 0.3620689655172414, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.17277863948592953, 0.5, 'BMI <= 23.05\nentropy = 2.288\nsamples = 269\nvalue = [44, 44, 53, 51, 77]\nclass = Healthy'),
#  Text(0.1482484942489374, 0.46551724137931033, 'Blood Pressure <= 116.5\nentropy = 2.315\nsamples = 198\nvalue = [36, 37, 37, 42, 46]\nclass = Healthy'),
#  Text(0.12958523860362992, 0.43103448275862066, 'Blood Pressure <= 107.5\nentropy = 2.199\nsamples = 77\nvalue = [14.0, 17.0, 5.0, 19.0, 22.0]\nclass = Healthy'),
#  Text(0.12549604173800938, 0.39655172413793105, 'Age <= 52.5\nentropy = 2.193\nsamples = 58\nvalue = [7, 16, 5, 16, 14]\nclass = Iron Deficiency'),
#  Text(0.12150756400701006, 0.3620689655172414, 'Heart Rate <= 84.0\nentropy = 2.171\nsamples = 37\nvalue = [4, 14, 5, 8, 6]\nclass = Iron Deficiency'),
#  Text(0.11868742823761658, 0.3275862068965517, 'Weight <= 86.4\nentropy = 1.85\nsamples = 30\nvalue = [0, 13, 4, 8, 5]\nclass = Iron Deficiency'),
#  Text(0.11627016900670789, 0.29310344827586204, 'Height <= 175.75\nentropy = 1.545\nsamples = 21\nvalue = [0, 9, 0, 7, 5]\nclass = Iron Deficiency'),
#  Text(0.11465866285276877, 0.25862068965517243, 'Iron <= 73.3\nentropy = 1.371\nsamples = 15\nvalue = [0, 9, 0, 3, 3]\nclass = Iron Deficiency'),
#  Text(0.11336945792961747, 0.22413793103448276, 'Age <= 49.5\nentropy = 0.811\nsamples = 4\nvalue = [0, 1, 0, 0, 3]\nclass = Healthy'),
#  Text(0.11272485546804181, 0.1896551724137931, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]\nclass = Healthy'),
#  Text(0.11401406039119312, 0.1896551724137931, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
# ...
#  Text(0.3326501218701529, 0.5344827586206896, 'BMI <= 34.3\nentropy = 2.292\nsamples = 134\nvalue = [19.0, 35.0, 23.0, 28.0, 29.0]\nclass = Iron Deficiency'),
#  Text(0.3250307193360595, 0.5, 'Vitamin D <= 57.0\nentropy = 2.274\nsamples = 122\nvalue = [18, 35, 18, 27, 24]\nclass = Iron Deficiency'),
#  Text(0.3136595290373265, 0.46551724137931033, 'Age <= 37.0\nentropy = 2.258\nsamples = 116\nvalue = [18, 34, 14, 26, 24]\nclass = Iron Deficiency'),
#  Text(0.2989343915557078, 0.43103448275862066, 'Weight <= 57.75\nentropy = 1.95\nsamples = 35\nvalue = [7, 11, 0, 11, 6]\nclass = Iron Deficiency'),
#  Text(0.2964365570171021, 0.39655172413793105, 'Cholesterol <= 217.3\nentropy = 1.299\nsamples = 8\nvalue = [5, 1, 0, 2, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.2957919545555265, 0.3620689655172414, 'Age <= 30.0\nentropy = 1.5\nsamples = 4\nvalue = [1, 1, 0, 2, 0]\nclass = Obesity'),
#  Text(0.2951473520939508, 0.3275862068965517, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]\nclass = Obesity'),
#  Text(0.2964365570171021, 0.3275862068965517, 'Height <= 162.95\nentropy = 1.0\nsamples = 2\nvalue = [1, 1, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.2957919545555265, 0.29310344827586204, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.29708115947867775, 0.29310344827586204, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.29708115947867775, 0.3620689655172414, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.3014322260943134, 0.39655172413793105, 'Calcium <= 9.15\nentropy = 1.819\nsamples = 27\nvalue = [2, 10, 0, 9, 6]\nclass = Iron Deficiency'),
#  Text(0.29965956932498033, 0.3620689655172414, 'Vitamin D <= 46.4\nentropy = 0.994\nsamples = 11\nvalue = [0, 6, 0, 5, 0]\nclass = Iron Deficiency'),
#  Text(0.29901496686340473, 0.3275862068965517, 'Cholesterol <= 204.85\nentropy = 0.863\nsamples = 7\nvalue = [0, 2, 0, 5, 0]\nclass = Obesity'),
#  Text(0.29837036440182907, 0.29310344827586204, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0]\nclass = Obesity'),
#  Text(0.29965956932498033, 0.29310344827586204, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.300304171786556, 0.3275862068965517, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.30320488286364644, 0.3620689655172414, 'Cholesterol <= 189.75\nentropy = 1.906\nsamples = 16\nvalue = [2, 4, 0, 4, 6]\nclass = Healthy'),
#  Text(0.3015933767097073, 0.3275862068965517, 'Iron <= 133.75\nentropy = 0.722\nsamples = 5\nvalue = [1, 0, 0, 0, 4]\nclass = Healthy'),
#  Text(0.30094877424813166, 0.29310344827586204, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]\nclass = Healthy'),
#  Text(0.302237979171283, 0.29310344827586204, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.30481638901758557, 0.3275862068965517, 'BMI <= 29.6\nentropy = 1.823\nsamples = 11\nvalue = [1, 4, 0, 4, 2]\nclass = Iron Deficiency'),
#  Text(0.30352718409443424, 0.29310344827586204, 'Blood Pressure <= 127.972\nentropy = 1.5\nsamples = 4\nvalue = [1, 0, 0, 1, 2]\nclass = Healthy'),
#  Text(0.3028825816328586, 0.25862068965517243, 'Glucose <= 113.95\nentropy = 1.0\nsamples = 2\nvalue = [1, 0, 0, 1, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.302237979171283, 0.22413793103448276, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.30352718409443424, 0.22413793103448276, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.3041717865560099, 0.25862068965517243, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]\nclass = Healthy'),
#  Text(0.3061055939407369, 0.29310344827586204, 'Weight <= 78.35\nentropy = 0.985\nsamples = 7\nvalue = [0, 4, 0, 3, 0]\nclass = Iron Deficiency'),
#  Text(0.3054609914791612, 0.25862068965517243, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.3067501964023125, 0.25862068965517243, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0]\nclass = Obesity'),
#  Text(0.32838466651894527, 0.43103448275862066, 'Iron <= 135.05\nentropy = 2.277\nsamples = 81\nvalue = [11, 23, 14, 15, 18]\nclass = Iron Deficiency'),
#  Text(0.3216566283262494, 0.39655172413793105, 'Age <= 60.5\nentropy = 2.268\nsamples = 72\nvalue = [11, 22, 11, 15, 13]\nclass = Iron Deficiency'),
#  Text(0.31400197409503855, 0.3620689655172414, 'Weight <= 53.65\nentropy = 2.314\nsamples = 54\nvalue = [11, 13, 10, 10, 10]\nclass = Iron Deficiency'),
#  Text(0.30997320871019074, 0.3275862068965517, 'Cholesterol <= 185.5\nentropy = 1.352\nsamples = 9\nvalue = [0, 0, 3, 5, 1]\nclass = Obesity'),
#  Text(0.3086840037870395, 0.29310344827586204, 'Height <= 164.7\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 0, 4, 1]\nclass = Obesity'),
#  Text(0.3080394013254638, 0.25862068965517243, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Healthy'),
#  Text(0.30932860624861513, 0.25862068965517243, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0]\nclass = Obesity'),
#  Text(0.31126241363334206, 0.29310344827586204, 'Iron <= 113.3\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 3, 1, 0]\nclass = High BP'),
#  Text(0.3106178111717664, 0.25862068965517243, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.3119070160949177, 0.25862068965517243, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0]\nclass = High BP'),
#  Text(0.3180307394798864, 0.3275862068965517, 'Weight <= 73.35\nentropy = 2.249\nsamples = 45\nvalue = [11.0, 13.0, 7.0, 5.0, 9.0]\nclass = Iron Deficiency'),
#  Text(0.3148077271720081, 0.29310344827586204, 'Heart Rate <= 76.5\nentropy = 1.855\nsamples = 23\nvalue = [5, 12, 2, 1, 3]\nclass = Iron Deficiency'),
#  Text(0.313196221018069, 0.25862068965517243, 'Heart Rate <= 57.0\nentropy = 1.45\nsamples = 17\nvalue = [5, 10, 1, 1, 0]\nclass = Iron Deficiency'),
#  Text(0.3119070160949177, 0.22413793103448276, 'Height <= 163.8\nentropy = 0.918\nsamples = 3\nvalue = [2, 0, 0, 1, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.31126241363334206, 0.1896551724137931, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.3125516185564934, 0.1896551724137931, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.3144854259412203, 0.22413793103448276, 'Cholesterol <= 155.5\nentropy = 1.095\nsamples = 14\nvalue = [3, 10, 1, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.31384082347964465, 0.1896551724137931, 'Blood Pressure <= 100.0\nentropy = 1.371\nsamples = 5\nvalue = [3, 1, 1, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.313196221018069, 0.15517241379310345, 'Age <= 45.5\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 1, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.3125516185564934, 0.1206896551724138, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.31384082347964465, 0.1206896551724138, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.3144854259412203, 0.15517241379310345, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.31513002840279597, 0.1896551724137931, 'entropy = 0.0\nsamples = 9\nvalue = [0, 9, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.3164192333259473, 0.25862068965517243, 'Blood Pressure <= 126.0\nentropy = 1.459\nsamples = 6\nvalue = [0, 2, 1, 0, 3]\nclass = Healthy'),
#  Text(0.31577463086437163, 0.22413793103448276, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.3170638357875229, 0.22413793103448276, 'Vitamin D <= 48.8\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 1, 0, 3]\nclass = Healthy'),
#  Text(0.3164192333259473, 0.1896551724137931, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]\nclass = Healthy'),
#  Text(0.31770843824909856, 0.1896551724137931, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.32125375178776466, 0.29310344827586204, 'Iron <= 123.25\nentropy = 2.158\nsamples = 22\nvalue = [6, 1, 5, 4, 6]\nclass = Vitamin D Deficiency'),
#  Text(0.3189976431722499, 0.25862068965517243, 'BMI <= 26.75\nentropy = 1.555\nsamples = 12\nvalue = [0, 0, 3, 4, 5]\nclass = Healthy'),
#  Text(0.3183530407106742, 0.22413793103448276, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0]\nclass = High BP'),
#  Text(0.31964224563382554, 0.22413793103448276, 'Glucose <= 108.05\nentropy = 0.991\nsamples = 9\nvalue = [0, 0, 0, 4, 5]\nclass = Healthy'),
#  Text(0.3189976431722499, 0.1896551724137931, 'Calcium <= 9.55\nentropy = 0.722\nsamples = 5\nvalue = [0, 0, 0, 4, 1]\nclass = Obesity'),
#  Text(0.3183530407106742, 0.15517241379310345, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Healthy'),
#  Text(0.31964224563382554, 0.15517241379310345, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0]\nclass = Obesity'),
#  Text(0.32028684809540114, 0.1896551724137931, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]\nclass = Healthy'),
#  Text(0.3235098604032794, 0.25862068965517243, 'Heart Rate <= 87.5\nentropy = 1.571\nsamples = 10\nvalue = [6, 1, 2, 0, 1]\nclass = Vitamin D Deficiency'),
#  Text(0.3222206554801281, 0.22413793103448276, 'Heart Rate <= 59.5\nentropy = 1.061\nsamples = 8\nvalue = [6, 0, 1, 0, 1]\nclass = Vitamin D Deficiency'),
#  Text(0.32157605301855247, 0.1896551724137931, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.3228652579417038, 0.1896551724137931, 'Cholesterol <= 137.35\nentropy = 0.592\nsamples = 7\nvalue = [6, 0, 0, 0, 1]\nclass = Vitamin D Deficiency'),
#  Text(0.3222206554801281, 0.15517241379310345, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Healthy'),
#  Text(0.3235098604032794, 0.15517241379310345, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.3247990653264307, 0.22413793103448276, 'Calcium <= 9.45\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 1, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.32415446286485505, 0.1896551724137931, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.3254436677880064, 0.1896551724137931, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.3293112825574603, 0.3620689655172414, 'Blood Pressure <= 113.5\nentropy = 1.676\nsamples = 18\nvalue = [0, 9, 1, 5, 3]\nclass = Iron Deficiency'),
#  Text(0.32673287271115764, 0.3275862068965517, 'Vitamin D <= 26.3\nentropy = 1.561\nsamples = 8\nvalue = [0, 2, 0, 3, 3]\nclass = Obesity'),
#  Text(0.3254436677880064, 0.29310344827586204, 'Cholesterol <= 222.3\nentropy = 0.811\nsamples = 4\nvalue = [0, 1, 0, 3, 0]\nclass = Obesity'),
#  Text(0.3247990653264307, 0.25862068965517243, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0]\nclass = Obesity'),
#  Text(0.32608827024958204, 0.25862068965517243, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.32802207763430896, 0.29310344827586204, 'BMI <= 28.95\nentropy = 0.811\nsamples = 4\nvalue = [0, 1, 0, 0, 3]\nclass = Healthy'),
#  Text(0.3273774751727333, 0.25862068965517243, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.3286666800958846, 0.25862068965517243, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]\nclass = Healthy'),
#  Text(0.33188969240376287, 0.3275862068965517, 'BMI <= 26.85\nentropy = 1.157\nsamples = 10\nvalue = [0, 7, 1, 2, 0]\nclass = Iron Deficiency'),
#  Text(0.33060048748061155, 0.29310344827586204, 'Vitamin D <= 29.05\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 1, 0]\nclass = High BP'),
#  Text(0.32995588501903594, 0.25862068965517243, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.3312450899421872, 0.25862068965517243, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.3331788973269142, 0.29310344827586204, 'Cholesterol <= 249.75\nentropy = 0.544\nsamples = 8\nvalue = [0, 7, 0, 1, 0]\nclass = Iron Deficiency'),
#  Text(0.33253429486533853, 0.25862068965517243, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.3338234997884898, 0.25862068965517243, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.3351127047116411, 0.39655172413793105, 'Cholesterol <= 240.0\nentropy = 1.352\nsamples = 9\nvalue = [0, 1, 3, 0, 5]\nclass = Healthy'),
#  Text(0.3338234997884898, 0.3620689655172414, 'Cholesterol <= 147.5\nentropy = 0.722\nsamples = 5\nvalue = [0, 1, 0, 0, 4]\nclass = Healthy'),
#  Text(0.3331788973269142, 0.3275862068965517, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.33446810225006546, 0.3275862068965517, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]\nclass = Healthy'),
#  Text(0.33640190963479244, 0.3620689655172414, 'Calcium <= 9.05\nentropy = 0.811\nsamples = 4\nvalue = [0, 0, 3, 0, 1]\nclass = High BP'),
#  Text(0.3357573071732168, 0.3275862068965517, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]\nclass = Healthy'),
#  Text(0.33704651209636804, 0.3275862068965517, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0]\nclass = High BP'),
#  Text(0.33640190963479244, 0.46551724137931033, 'Weight <= 52.0\nentropy = 1.252\nsamples = 6\nvalue = [0, 1, 4, 1, 0]\nclass = High BP'),
#  Text(0.3357573071732168, 0.43103448275862066, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.33704651209636804, 0.43103448275862066, 'Glucose <= 126.053\nentropy = 0.722\nsamples = 5\nvalue = [0, 1, 4, 0, 0]\nclass = High BP'),
#  Text(0.33640190963479244, 0.39655172413793105, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0]\nclass = High BP'),
#  Text(0.3376911145579437, 0.39655172413793105, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.3402695244042463, 0.5, 'Cholesterol <= 163.9\nentropy = 1.65\nsamples = 12\nvalue = [1, 0, 5, 1, 5]\nclass = High BP'),
#  Text(0.338980319481095, 0.46551724137931033, 'Iron <= 109.75\nentropy = 0.722\nsamples = 5\nvalue = [1, 0, 4, 0, 0]\nclass = High BP'),
#  Text(0.33833571701951937, 0.43103448275862066, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.3396249219426707, 0.43103448275862066, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0]\nclass = High BP'),
#  Text(0.3415587293273976, 0.46551724137931033, 'Glucose <= 80.8\nentropy = 1.149\nsamples = 7\nvalue = [0, 0, 1, 1, 5]\nclass = Healthy'),
#  Text(0.34091412686582195, 0.43103448275862066, 'Weight <= 93.8\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 1, 0]\nclass = High BP'),
#  Text(0.3402695244042463, 0.39655172413793105, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]\nclass = Obesity'),
#  Text(0.3415587293273976, 0.39655172413793105, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  Text(0.3422033317889733, 0.43103448275862066, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5]\nclass = Healthy'),
#  Text(0.3422033317889733, 0.5344827586206896, 'Age <= 55.5\nentropy = 0.65\nsamples = 6\nvalue = [0, 1, 5, 0, 0]\nclass = High BP'),
#  Text(0.3415587293273976, 0.5, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0]\nclass = High BP'),
#  Text(0.34284793425054894, 0.5, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]\nclass = Iron Deficiency'),
#  Text(0.3460709465584272, 0.5689655172413793, 'Height <= 165.65\nentropy = 1.592\nsamples = 14\nvalue = [6, 1, 1, 6, 0]\nclass = Vitamin D Deficiency'),
#  Text(0.34478174163527586, 0.5344827586206896, 'Vitamin D <= 49.15\nentropy = 1.224\nsamples = 9\nvalue = [2, 0, 1, 6, 0]\nclass = Obesity'),
#  Text(0.3441371391737002, 0.5, 'Weight <= 93.35\nentropy = 0.592\nsamples = 7\nvalue = [0, 0, 1, 6, 0]\nclass = Obesity'),
#  Text(0.3434925367121246, 0.46551724137931033, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0]\nclass = Obesity'),
#  Text(0.34478174163527586, 0.46551724137931033, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]\nclass = High BP'),
#  ...]
