# %%
import matplotlib.pyplot as plt

# %%
Area = [2600,3000,3200,3600,4000,3500]
Price= [5500000,6100000,6250000,6800000,7100000,None]
plt.xlabel("Area ")
plt.ylabel("Price")
plt.title("Scattered Plot")
plt.scatter(Area, Price)
plt.show()
