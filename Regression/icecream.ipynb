# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Ice_cream selling data.csv")
df
# Out:
#     Temperature (°C)  Ice Cream Sales (units)
# 0          -4.662263                41.842986
# 1          -4.316559                34.661120
# 2          -4.213985                39.383001
# 3          -3.949661                37.539845
# 4          -3.578554                32.284531
# 5          -3.455712                30.001138
# 6          -3.108440                22.635401
# 7          -3.081303                25.365022
# 8          -2.672461                19.226970
# 9          -2.652287                20.279679
# 10         -2.651498                13.275828
# 11         -2.288264                18.123991
# 12         -2.111870                11.218294
# 13         -1.818938                10.012868
# 14         -1.660348                12.615181
# 15         -1.326379                10.957731
# 16         -1.173123                 6.689123
# 17         -0.773330                 9.392969
# 18         -0.673753                 5.210163
# ...

# %%
df.shape
# Out:
# (49, 2)

# %%
df.tail()
# Out:
#     Temperature (°C)  Ice Cream Sales (units)
# 44          3.610778                28.912188
# 45          3.704057                17.843957
# 46          4.130868                34.530743
# 47          4.133534                27.698383
# 48          4.899032                41.514822

# %%
df.head()
# Out:
#    Temperature (°C)  Ice Cream Sales (units)
# 0         -4.662263                41.842986
# 1         -4.316559                34.661120
# 2         -4.213985                39.383001
# 3         -3.949661                37.539845
# 4         -3.578554                32.284531

# %%
df.dtypes
# Out:
# Temperature (°C)           float64
# Ice Cream Sales (units)    float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Temperature (°C)           0
# Ice Cream Sales (units)    0
# dtype: int64

# %%
x=df.iloc[:,:-1]
x
# Out:
#     Temperature (°C)
# 0          -4.662263
# 1          -4.316559
# 2          -4.213985
# 3          -3.949661
# 4          -3.578554
# 5          -3.455712
# 6          -3.108440
# 7          -3.081303
# 8          -2.672461
# 9          -2.652287
# 10         -2.651498
# 11         -2.288264
# 12         -2.111870
# 13         -1.818938
# 14         -1.660348
# 15         -1.326379
# 16         -1.173123
# 17         -0.773330
# 18         -0.673753
# 19         -0.149635
# 20         -0.036156
# 21         -0.033895
# 22          0.008608
# 23          0.149245
# 24          0.688781
# 25          0.693599
# 26          0.874905
# 27          1.024181
# 28          1.240712
# 29          1.359813
# 30          1.740000
# 31          1.850552
# 32          1.999310
# 33          2.075101
# 34          2.318591
# 35          2.471946
# 36          2.784836
# 37          2.831760
# 38          2.959932
# 39          3.020874
# 40          3.211366
# 41          3.270044
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0     41.842986
# 1     34.661120
# 2     39.383001
# 3     37.539845
# 4     32.284531
# 5     30.001138
# 6     22.635401
# 7     25.365022
# 8     19.226970
# 9     20.279679
# 10    13.275828
# 11    18.123991
# 12    11.218294
# 13    10.012868
# 14    12.615181
# 15    10.957731
# 16     6.689123
# 17     9.392969
# 18     5.210163
# 19     4.673643
# 20     0.328626
# 21     0.897603
# 22     3.165600
# 23     1.931416
# 24     2.576782
# 25     4.625689
# 26     0.789974
# 27     2.313806
# 28     1.292361
# 29     0.953115
# 30     3.782570
# 31     4.857988
# 32     8.943823
# 33     8.170735
# 34     7.412094
# 35    10.336631
# 36    15.996620
# 37    12.568237
# 38    21.342916
# 39    20.114413
# 40    22.839406
# 41    16.983279
# 42    25.142082
# 43    26.104740
# 44    28.912188
# 45    17.843957
# 46    34.530743
# 47    27.698383
# 48    41.514822
# Name: Ice Cream Sales (units), dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
y_pred=model.predict(x)
y_pred
# Out:
# array([19.83504165, 19.55970386, 19.47800752, 19.26748505, 18.97191395,
#        18.87407555, 18.59748863, 18.57587533, 18.25024982, 18.23418207,
#        18.23355385, 17.94425352, 17.80376302, 17.57045518, 17.44414515,
#        17.17815336, 17.05609176, 16.7376736 , 16.6583646 , 16.24092715,
#        16.15054649, 16.14874553, 16.11489373, 16.00288249, 15.57316494,
#        15.56932764, 15.42492506, 15.3060333 , 15.1335758 , 15.03871692,
#        14.73591401, 14.64786415, 14.52938443, 14.46902077, 14.27509091,
#        14.15295043, 13.90374659, 13.86637384, 13.76429043, 13.71575256,
#        13.56403399, 13.51729954, 13.48063985, 13.4648223 , 13.2459192 ,
#        13.17162651, 12.83169023, 12.82956701, 12.21988091])

# %%
plt.scatter(x,y)
plt.plot(x,y_pred)

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score
mape=mean_absolute_percentage_error(y,y_pred)
score=r2_score(y,y_pred)
mape,score
# Out:
# (3.2511805873785518, 0.030689536411547258)

# %%
from sklearn.preprocessing import PolynomialFeatures
features=PolynomialFeatures(degree=2)
x_poly=features.fit_transform(x)
model1=LinearRegression()
model1.fit(x_poly,y)
y_poly=model1.predict(x_poly)
y_poly
# Out:
# array([46.56450722, 40.60054839, 38.9150888 , 34.7492721 , 29.33194015,
#        27.64973483, 23.19286196, 22.86317757, 18.2222657 , 18.00909784,
#        18.0007937 , 14.41854119, 12.85306964, 10.50486845,  9.36458732,
#         7.26426571,  6.43705471,  4.68365396,  4.33790607,  3.11613947,
#         2.98398348,  2.9818289 ,  2.9448111 ,  2.86944566,  3.25171143,
#         3.25992325,  3.63068299,  4.02622586,  4.74489126,  5.21332116,
#         7.05590173,  7.69094811,  8.61603854,  9.11849441, 10.8749611 ,
#        12.09255676, 14.84372119, 15.2871989 , 16.53961394, 17.15618838,
#        19.17109013, 19.81849706, 20.33515682, 20.56047398, 23.82688427,
#        24.99828169, 30.76428693, 30.80239561, 42.82119482])

# %%
mape1=mean_absolute_percentage_error(y,y_poly)
score2=r2_score(y,y_poly)
mape1,score2
# Out:
# (0.6258942344825256, 0.9321137090423876)

# %%
plt.scatter(x,y)
plt.plot(x,y_poly)

# %%
df2=pd.DataFrame({'Actual value':y,'simple linear regression':y_pred,'polynomial regression':y_poly})
df2
# Out:
#     Actual value  simple linear regression  polynomial regression
# 0      41.842986                 19.835042              46.564507
# 1      34.661120                 19.559704              40.600548
# 2      39.383001                 19.478008              38.915089
# 3      37.539845                 19.267485              34.749272
# 4      32.284531                 18.971914              29.331940
# 5      30.001138                 18.874076              27.649735
# 6      22.635401                 18.597489              23.192862
# 7      25.365022                 18.575875              22.863178
# 8      19.226970                 18.250250              18.222266
# 9      20.279679                 18.234182              18.009098
# 10     13.275828                 18.233554              18.000794
# 11     18.123991                 17.944254              14.418541
# 12     11.218294                 17.803763              12.853070
# ...
