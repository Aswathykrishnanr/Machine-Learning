# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('carclaims.csv')
df
# Out:
#       Month  WeekOfMonth  DayOfWeek     Make AccidentArea DayOfWeekClaimed  \
# 0       Dec            5  Wednesday    Honda        Urban          Tuesday
# 1       Jan            3  Wednesday    Honda        Urban           Monday
# 2       Oct            5     Friday    Honda        Urban         Thursday
# 3       Jun            2   Saturday   Toyota        Rural           Friday
# 4       Jan            5     Monday    Honda        Urban          Tuesday
# ...     ...          ...        ...      ...          ...              ...
# 15415   Nov            4     Friday   Toyota        Urban          Tuesday
# 15416   Nov            5   Thursday  Pontiac        Urban           Friday
# 15417   Nov            5   Thursday   Toyota        Rural           Friday
# 15418   Dec            1     Monday   Toyota        Urban         Thursday
# 15419   Dec            2  Wednesday   Toyota        Urban         Thursday
#
#       MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  \
# ...

# %%
df.head()
# Out:
#   Month  WeekOfMonth  DayOfWeek    Make AccidentArea DayOfWeekClaimed  \
# 0   Dec            5  Wednesday   Honda        Urban          Tuesday
# 1   Jan            3  Wednesday   Honda        Urban           Monday
# 2   Oct            5     Friday   Honda        Urban         Thursday
# 3   Jun            2   Saturday  Toyota        Rural           Friday
# 4   Jan            5     Monday   Honda        Urban          Tuesday
#
#   MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  \
# 0          Jan                   1  Female        Single  ...
# 1          Jan                   4    Male        Single  ...
# 2          Nov                   2    Male       Married  ...
# 3          Jul                   1    Male       Married  ...
# 4          Feb                   2  Female        Single  ...
#
#    AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# 0           26 to 30                No             No  External
# ...

# %%
df.tail()
# Out:
#       Month  WeekOfMonth  DayOfWeek     Make AccidentArea DayOfWeekClaimed  \
# 15415   Nov            4     Friday   Toyota        Urban          Tuesday
# 15416   Nov            5   Thursday  Pontiac        Urban           Friday
# 15417   Nov            5   Thursday   Toyota        Rural           Friday
# 15418   Dec            1     Monday   Toyota        Urban         Thursday
# 15419   Dec            2  Wednesday   Toyota        Urban         Thursday
#
#       MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  \
# 15415          Nov                   5    Male       Married  ...
# 15416          Dec                   1    Male       Married  ...
# 15417          Dec                   1    Male        Single  ...
# 15418          Dec                   2  Female       Married  ...
# 15419          Dec                   3    Male        Single  ...
#
#        AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# ...

# %%
#Are claims more frequent during certain months?
month_count=df['MonthClaimed'].value_counts()
print(month_count)
# Out:
# MonthClaimed
# Jan    1446
# May    1411
# Mar    1348
# Oct    1339
# Jun    1293
# Feb    1287
# Nov    1285
# Apr    1271
# Sep    1242
# Jul    1225
# Dec    1146
# Aug    1126
# 0         1
# Name: count, dtype: int64

# %%
plt.bar(month_count.index,month_count.values)
# Out:
# <BarContainer object of 13 artists>

# %%
df.shape
# Out:
# (15420, 33)

# %%
df.dtypes
# Out:
# Month                   object
# WeekOfMonth              int64
# DayOfWeek               object
# Make                    object
# AccidentArea            object
# DayOfWeekClaimed        object
# MonthClaimed            object
# WeekOfMonthClaimed       int64
# Sex                     object
# MaritalStatus           object
# Age                      int64
# Fault                   object
# PolicyType              object
# VehicleCategory         object
# VehiclePrice            object
# PolicyNumber             int64
# RepNumber                int64
# Deductible               int64
# DriverRating             int64
# Days:Policy-Accident    object
# Days:Policy-Claim       object
# PastNumberOfClaims      object
# AgeOfVehicle            object
# AgeOfPolicyHolder       object
# PoliceReportFiled       object
# WitnessPresent          object
# AgentType               object
# NumberOfSuppliments     object
# AddressChange-Claim     object
# NumberOfCars            object
# ...

# %%
df.isna().sum()
# Out:
# Month                   0
# WeekOfMonth             0
# DayOfWeek               0
# Make                    0
# AccidentArea            0
# DayOfWeekClaimed        0
# MonthClaimed            0
# WeekOfMonthClaimed      0
# Sex                     0
# MaritalStatus           0
# Age                     0
# Fault                   0
# PolicyType              0
# VehicleCategory         0
# VehiclePrice            0
# PolicyNumber            0
# RepNumber               0
# Deductible              0
# DriverRating            0
# Days:Policy-Accident    0
# Days:Policy-Claim       0
# PastNumberOfClaims      0
# AgeOfVehicle            0
# AgeOfPolicyHolder       0
# PoliceReportFiled       0
# WitnessPresent          0
# AgentType               0
# NumberOfSuppliments     0
# AddressChange-Claim     0
# NumberOfCars            0
# Year                    0
# BasePolicy              0
# FraudFound              0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
total_claims = len(df)

# %%
Overall_fraud_counts = df['FraudFound'].value_counts()
fraud_percent = ( Overall_fraud_counts/ total_claims) * 100
print("Overall_percentage", fraud_percent)
plt.bar(fraud_percent.index,fraud_percent.values)
# Out:
# Overall_percentage FraudFound
# No     94.014267
# Yes     5.985733
# Name: count, dtype: float64
# <BarContainer object of 2 artists>

# %%
df4=df['Make'].value_counts()
df4
# Out:
# Make
# Pontiac      3837
# Toyota       3121
# Honda        2801
# Mazda        2354
# Chevrolet    1681
# Accura        472
# Ford          450
# VW            283
# Dodge         109
# Saab          108
# Mercury        83
# Saturn         58
# Nisson         30
# BMW            15
# Jaguar          6
# Porche          5
# Mecedes         4
# Ferrari         2
# Lexus           1
# Name: count, dtype: int64

# %%
plt.bar(df4.index,df4.values)
# Out:
# <BarContainer object of 19 artists>

# %%
df2=df['Sex'].value_counts()
df2
# Out:
# Sex
# Male      13000
# Female     2420
# Name: count, dtype: int64

# %%
plt.bar(df2.index,df2.values,color='r')
# Out:
# <BarContainer object of 2 artists>

# %%
Accidental_area=df['AccidentArea'].value_counts()
Accidental_area
# Out:
# AccidentArea
# Urban    13822
# Rural     1598
# Name: count, dtype: int64

# %%
plt.bar(Accidental_area.index,Accidental_area.values)
# Out:
# <BarContainer object of 2 artists>

# %%
df.dtypes
# Out:
# Month                   object
# WeekOfMonth              int64
# DayOfWeek               object
# Make                    object
# AccidentArea            object
# DayOfWeekClaimed        object
# MonthClaimed            object
# WeekOfMonthClaimed       int64
# Sex                     object
# MaritalStatus           object
# Age                      int64
# Fault                   object
# PolicyType              object
# VehicleCategory         object
# VehiclePrice            object
# PolicyNumber             int64
# RepNumber                int64
# Deductible               int64
# DriverRating             int64
# Days:Policy-Accident    object
# Days:Policy-Claim       object
# PastNumberOfClaims      object
# AgeOfVehicle            object
# AgeOfPolicyHolder       object
# PoliceReportFiled       object
# WitnessPresent          object
# AgentType               object
# NumberOfSuppliments     object
# AddressChange-Claim     object
# NumberOfCars            object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
df['FraudFound']=lab.fit_transform(df['FraudFound'])

# %%
df
# Out:
#       Month  WeekOfMonth  DayOfWeek     Make AccidentArea DayOfWeekClaimed  \
# 0       Dec            5  Wednesday    Honda        Urban          Tuesday
# 1       Jan            3  Wednesday    Honda        Urban           Monday
# 2       Oct            5     Friday    Honda        Urban         Thursday
# 3       Jun            2   Saturday   Toyota        Rural           Friday
# 4       Jan            5     Monday    Honda        Urban          Tuesday
# ...     ...          ...        ...      ...          ...              ...
# 15415   Nov            4     Friday   Toyota        Urban          Tuesday
# 15416   Nov            5   Thursday  Pontiac        Urban           Friday
# 15417   Nov            5   Thursday   Toyota        Rural           Friday
# 15418   Dec            1     Monday   Toyota        Urban         Thursday
# 15419   Dec            2  Wednesday   Toyota        Urban         Thursday
#
#       MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  \
# ...

# %%
#In which make of vehicle undergoes the greatest number of fraud claims?
Make_Claimed = df.groupby('Make')['FraudFound'].mean()*100
print(Make_Claimed)
Make_Claimed.sort_index()
# Out:
# Make
# Accura       12.500000
# BMW           6.666667
# Chevrolet     5.591910
# Dodge         1.834862
# Ferrari       0.000000
# Ford          7.333333
# Honda         6.390575
# Jaguar        0.000000
# Lexus         0.000000
# Mazda         5.225149
# Mecedes      25.000000
# Mercury       7.228916
# Nisson        3.333333
# Pontiac       5.551212
# Porche        0.000000
# Saab         10.185185
# Saturn       10.344828
# Toyota        5.959628
# VW            2.826855
# Name: FraudFound, dtype: float64
# Make
# Accura       12.500000
# BMW           6.666667
# Chevrolet     5.591910
# Dodge         1.834862
# Ferrari       0.000000
# Ford          7.333333
# Honda         6.390575
# Jaguar        0.000000
# Lexus         0.000000
# Mazda         5.225149
# Mecedes      25.000000
# Mercury       7.228916
# Nisson        3.333333
# Pontiac       5.551212
# Porche        0.000000
# Saab         10.185185
# Saturn       10.344828
# Toyota        5.959628
# VW            2.826855
# ...

# %%
Make_Claimed.sort_values
# Out:
# <bound method Series.sort_values of Make
# Accura       12.500000
# BMW           6.666667
# Chevrolet     5.591910
# Dodge         1.834862
# Ferrari       0.000000
# Ford          7.333333
# Honda         6.390575
# Jaguar        0.000000
# Lexus         0.000000
# Mazda         5.225149
# Mecedes      25.000000
# Mercury       7.228916
# Nisson        3.333333
# Pontiac       5.551212
# Porche        0.000000
# Saab         10.185185
# Saturn       10.344828
# Toyota        5.959628
# VW            2.826855
# Name: FraudFound, dtype: float64>

# %%
plt.bar(Make_Claimed.index, Make_Claimed.values)
plt.ylabel("Fraud %")
plt.title("Fraud Percentage by Make")
plt.show()

# %%
df.shape
# Out:
# (15420, 33)

# %%
Area_Claimed1 = df.groupby('AccidentArea')['PolicyNumber'].mean()
print(Area_Claimed1)
# Out:
# AccidentArea
# Rural    7655.258448
# Urban    7716.886630
# Name: PolicyNumber, dtype: float64

# %%
plt.bar(Area_Claimed1.index, Area_Claimed1.values)
plt.ylabel("Fraud %")
plt.title("Fraud Percentage by Area")
plt.show()

# %%
Area_Claimed = df.groupby('AccidentArea')['FraudFound'].mean()*100
print(Area_Claimed)
# Out:
# AccidentArea
# Rural    8.322904
# Urban    5.715526
# Name: FraudFound, dtype: float64

# %%
Overall = df.groupby('FraudFound')['PolicyNumber'].mean()
print(Overall)
# Out:
# FraudFound
# 0    7733.351038
# 1    7351.592633
# Name: PolicyNumber, dtype: float64

# %%
plt.bar(Overall.index, Overall.values)
plt.ylabel("Fraud %")
plt.title("Fraud Percentage by Area")
plt.show()

# %%
df.dtypes
# Out:
# Month                   object
# WeekOfMonth              int64
# DayOfWeek               object
# Make                    object
# AccidentArea            object
# DayOfWeekClaimed        object
# MonthClaimed            object
# WeekOfMonthClaimed       int64
# Sex                     object
# MaritalStatus           object
# Age                      int64
# Fault                   object
# PolicyType              object
# VehicleCategory         object
# VehiclePrice            object
# PolicyNumber             int64
# RepNumber                int64
# Deductible               int64
# DriverRating             int64
# Days:Policy-Accident    object
# Days:Policy-Claim       object
# PastNumberOfClaims      object
# AgeOfVehicle            object
# AgeOfPolicyHolder       object
# PoliceReportFiled       object
# WitnessPresent          object
# AgentType               object
# NumberOfSuppliments     object
# AddressChange-Claim     object
# NumberOfCars            object
# ...

# %%
df.drop(['RepNumber','Year','DayOfWeekClaimed','MonthClaimed','WeekOfMonthClaimed','NumberOfSuppliments','AddressChange-Claim','Days:Policy-Accident','Days:Policy-Claim','PastNumberOfClaims'],axis=1,inplace=True)
df
# Out:
#       Month  WeekOfMonth  DayOfWeek     Make AccidentArea     Sex  \
# 0       Dec            5  Wednesday    Honda        Urban  Female
# 1       Jan            3  Wednesday    Honda        Urban    Male
# 2       Oct            5     Friday    Honda        Urban    Male
# 3       Jun            2   Saturday   Toyota        Rural    Male
# 4       Jan            5     Monday    Honda        Urban  Female
# ...     ...          ...        ...      ...          ...     ...
# 15415   Nov            4     Friday   Toyota        Urban    Male
# 15416   Nov            5   Thursday  Pontiac        Urban    Male
# 15417   Nov            5   Thursday   Toyota        Rural    Male
# 15418   Dec            1     Monday   Toyota        Urban  Female
# 15419   Dec            2  Wednesday   Toyota        Urban    Male
#
#       MaritalStatus  Age          Fault          PolicyType  ... Deductible  \
# 0            Single   21  Policy Holder   Sport - Liability  ...        300
# ...

# %%
df.dtypes
# Out:
# Month                object
# WeekOfMonth           int64
# DayOfWeek            object
# Make                 object
# AccidentArea         object
# Sex                  object
# MaritalStatus        object
# Age                   int64
# Fault                object
# PolicyType           object
# VehicleCategory      object
# VehiclePrice         object
# PolicyNumber          int64
# Deductible            int64
# DriverRating          int64
# AgeOfVehicle         object
# AgeOfPolicyHolder    object
# PoliceReportFiled    object
# WitnessPresent       object
# AgentType            object
# NumberOfCars         object
# BasePolicy           object
# FraudFound            int64
# dtype: object

# %%
df.corr(numeric_only=True)
# Out:
#               WeekOfMonth       Age  PolicyNumber  Deductible  DriverRating  \
# WeekOfMonth      1.000000 -0.004810     -0.007797   -0.003993     -0.016817
# Age             -0.004810  1.000000      0.025944    0.069420      0.001668
# PolicyNumber    -0.007797  0.025944      1.000000    0.002133     -0.012312
# Deductible      -0.003993  0.069420      0.002133    1.000000      0.003886
# DriverRating    -0.016817  0.001668     -0.012312    0.003886      1.000000
# FraudFound      -0.011861 -0.029741     -0.020345    0.017348      0.007266
#
#               FraudFound
# WeekOfMonth    -0.011861
# Age            -0.029741
# PolicyNumber   -0.020345
# Deductible      0.017348
# DriverRating    0.007266
# FraudFound      1.000000

# %%
cols_to_label_encode = ['Month','DayOfWeek','Make','AccidentArea','Sex','MaritalStatus','Fault','PolicyType','VehicleCategory','VehiclePrice','AgeOfVehicle','AgeOfPolicyHolder',
    'PoliceReportFiled',
    'WitnessPresent',
    'AgentType',
    'NumberOfCars',
    'BasePolicy'
]
for col in cols_to_label_encode:
    df[col] = lab.fit_transform(df[col])

# %%
x = df.drop("FraudFound", axis=1).values
y = df["FraudFound"].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
# array([[3, 1, 0, ..., 0, 0, 2],
#        [5, 4, 5, ..., 0, 0, 2],
#        [5, 2, 0, ..., 0, 0, 1],
#        ...,
#        [8, 2, 0, ..., 0, 0, 0],
#        [2, 4, 4, ..., 0, 0, 0],
#        [2, 4, 5, ..., 0, 0, 2]], shape=(10794, 22))

# %%
# from sklearn.preprocessing import StandardScaler
# scaler=StandardScaler()
# scaler.fit(x_train)   
# x_train=scaler.transform(x_train)
# x_test=scaler.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=100,criterion='entropy',max_depth=10,max_features='sqrt')
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(4626,))

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
score=accuracy_score(y_test,y_pred)
score
# Out:
# 0.9332036316472114

# %%
report=classification_report(y_test,y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97      4317
#            1       0.00      0.00      0.00       309
#
#     accuracy                           0.93      4626
#    macro avg       0.47      0.50      0.48      4626
# weighted avg       0.87      0.93      0.90      4626
# c:\Users\aswat\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\aswat\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
