# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Stats survey.csv')
df
# Out:
#                       Timestamp Your Sex?  \
# 0     2024/03/07 5:12:01 pm EET    Female
# 1     2024/03/07 5:12:08 pm EET      Male
# 2     2024/03/07 5:12:25 pm EET      Male
# 3     2024/03/07 5:12:28 pm EET      Male
# 4     2024/03/07 5:13:00 pm EET    Female
# ..                          ...       ...
# 401  2024/03/12 11:05:33 am EET    Female
# 402   2024/03/12 3:26:14 pm EET    Female
# 403  2024/03/13 10:32:19 pm EET    Female
# 404  2024/03/13 10:32:27 pm EET      Male
# 405  2024/03/16 10:30:36 pm EET    Female
#
#      Your Matric (grade 12) Average/ GPA (in %)  \
# 0                                          76.0
# 1                                          89.0
# 2                                          76.0
# 3                                          89.0
# 4                                          74.0
# ..                                          ...
# 401                                        74.0
# 402                                        73.0
# ...

# %%
df.dtypes
# Out:
# Timestamp                                                                                             object
# Your Sex?                                                                                             object
# Your Matric (grade 12) Average/ GPA (in %)                                                           float64
# What year were you in last year (2023) ?                                                              object
# What faculty does your degree fall under?                                                             object
# Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)                   float64
# Your Accommodation Status Last Year (2023)                                                            object
# Monthly Allowance in 2023                                                                             object
# Were you on scholarship/bursary in 2023?                                                              object
# ...

# %%
df.isna().sum()
# Out:
# Timestamp                                                                                             0
# Your Sex?                                                                                             2
# Your Matric (grade 12) Average/ GPA (in %)                                                            7
# What year were you in last year (2023) ?                                                             73
# What faculty does your degree fall under?                                                             7
# Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)                   86
# Your Accommodation Status Last Year (2023)                                                           23
# Monthly Allowance in 2023                                                                            31
# Were you on scholarship/bursary in 2023?                                                              8
# ...

# %%
df.drop(['Timestamp'],axis=1,inplace=True)

# %%
df.columns=['sex','GPA','Last Year','Faculty','2023 GPA','Accomodation','Monthly Allowance','Scholarship','Extra study hour','socialising','drinks per day','skipped class','Failed modules','romantic relationship','approve alcohol consumption','relationship status']
df
# Out:
#         sex   GPA Last Year                         Faculty  2023 GPA  \
# 0    Female  76.0  2nd Year          Arts & Social Sciences      72.0
# 1      Male  89.0  2nd Year  Economic & Management Sciences      75.0
# 2      Male  76.0  1st Year                    AgriSciences      55.0
# 3      Male  89.0  2nd Year                     Engineering      84.0
# 4    Female  74.0  2nd Year          Arts & Social Sciences      52.0
# ..      ...   ...       ...                             ...       ...
# 401  Female  74.0       NaN                         Science       NaN
# 402  Female  73.0  2nd Year  Economic & Management Sciences      58.0
# 403  Female  86.0  1st Year                             NaN       NaN
# 404    Male  85.0       NaN  Economic & Management Sciences       NaN
# 405  Female  80.0  1st Year                             NaN      63.0
#
#                                         Accomodation Monthly Allowance  \
# ...

# %%
df.dropna(subset=['2023 GPA'],inplace=True)

# %%
df.isna().sum()
# Out:
# sex                             0
# GPA                             2
# Last Year                       1
# Faculty                         3
# 2023 GPA                        0
# Accomodation                    2
# Monthly Allowance              14
# Scholarship                     0
# Extra study hour                0
# socialising                     0
# drinks per day                  0
# skipped class                   1
# Failed modules                  0
# romantic relationship           1
# approve alcohol consumption     1
# relationship status             1
# dtype: int64

# %%
df['GPA'].unique()
# Out:
# array([76.  , 89.  , 74.  , 80.  , 85.  , 79.  , 72.  , 87.  , 69.  ,
#        83.  , 78.  , 84.  , 86.  , 73.  , 99.  , 82.6 , 65.  , 81.  ,
#        88.  , 75.  , 98.  , 90.  , 98.33, 70.  ,   nan, 82.  , 77.  ,
#        68.  , 92.  , 91.86, 71.  , 63.  , 67.  , 95.  , 86.4 , 60.  ,
#        95.5 , 94.  , 66.  , 55.  , 64.  ])

# %%
df['Last Year'].unique()
# Out:
# array(['2nd Year', '1st Year', '3rd Year', '4th Year', 'Postgraduate',
#        nan], dtype=object)

# %%
df['Faculty'].unique()
# Out:
# array(['Arts & Social Sciences', 'Economic & Management Sciences',
#        'AgriSciences', 'Engineering', 'Science', 'Law',
#        'Medicine and Health Services', 'Education', nan], dtype=object)

# %%
df['Accomodation'].unique()
# Out:
# array(['Private accommodation/ stay with family/friends',
#        'Non-private accommodation ie. Res', nan], dtype=object)

# %%
df['Monthly Allowance'].unique()
# Out:
# array(['R 4001- R 5000', 'R 7001 - R 8000', 'R 6001 - R 7000',
#        'R 5001 - R 6000', 'R 8000+', nan], dtype=object)

# %%
df['skipped class'].unique()
# Out:
# array(['3', '4+', '2', '1', '0', nan], dtype=object)

# %%
df['romantic relationship'].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
df['approve alcohol consumption'].unique()
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
df['relationship status'].unique()
# Out:
# array(['Very close', 'Fair', 'Close', 'Distant', nan], dtype=object)

# %%
print(df['GPA'].skew())
# Out:
# 0.02965453380268074

# %%
df['GPA']=df['GPA'].fillna(df['GPA'].mean())
df['Last Year']=df['Last Year'].fillna(df['Last Year'].mode()[0])
df['Last Year']=df['Last Year'].fillna(df['Last Year'].mode()[0])
df['Faculty']=df['Faculty'].fillna(df['Faculty'].mode()[0])
df['Accomodation']=df['Accomodation'].fillna(df['Accomodation'].mode()[0])
df['Monthly Allowance']=df['Monthly Allowance'].fillna(df['Monthly Allowance'].mode()[0])
df['skipped class']=df['skipped class'].fillna(df['skipped class'].mode()[0])
df['Monthly Allowance']=df['Monthly Allowance'].fillna(df['Monthly Allowance'].mode()[0])
